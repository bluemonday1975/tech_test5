# %% [markdown]
# # Webアプリに入る前に知っておくべきデータに関する前提知識

# %% [markdown]
# ### 目標：APIを理解して使いこなし、そのデータを扱えるようになる事
#
# 目次
# https://docs.google.com/document/d/1crmJ0DjAl77ab9aK8K9DshfQu25fS3EWXCC0m4AajZo/edit

# %% [markdown]
# ## 3全体像：楽天のAPIから情報を取得する

# %% [markdown]
# ### 3.1.おさらい：APIとは？

# %% [markdown]
# APIは、Application Programming Interfaceの略であり、プログラムやアプリケーション開発に必要な機能やデータを提供するインターフェースを指します。
#
# 例として、スマートフォンにはカメラアプリや音楽アプリ、地図アプリなどが存在します。これらのアプリケーションは、スマートフォンのOS（Operating System）が提供するAPIを用いて、カメラやGPS機能といったハードウェアやソフトウェアにアクセスしています。
#
# APIはアプリケーションが他のアプリケーションやシステムと連携する手段であり、開発者が他のアプリケーションやサービスと容易に連携できるように設計されています。APIにはWeb API、データベースAPI、ソーシャルメディアAPIなど、多様な種類があります。
#
# オンラインランキングやアカウントログイン機能の開発の際、GoogleやFacebookなどのサービスが提供するAPIを利用してアカウント情報を取得することができます。
#
# APIは現代のソフトウェア開発において極めて重要な役割を担っており、様々なアプリケーションやサービスで利用されています。
#
# 今回取り上げる楽天APIを利用すれば、ホテルの価格比較サイトなどで活用することが可能です。

# %% [markdown]
# ### 3.2.実際にやる事

# %% [markdown]
# SimpleHotelSearchにアクセスして、沖縄の那覇市のホテル情報を取得します。

# %% [markdown]
# <img src="img/img032.jpg">

# %% [markdown]
# 参照：https://www.ebisumart.com/blog/ec-api/

# %%
import requests

#ライブラリrequestsを使うためにimportすることで機能を使う事が出来ます。
# アクセス先と認証と要求するデータの内容を指定します。
 #アクセス先を指定する必要があるので、アクセス先をREQUEST_URLという変数に代入しておきます。
# アクセスを許可されたユーザーという事を証明するために、APP_IDに認証IDを代入しておきます。
# アクセス先と認証を用意できたので、なんのデータが欲しいかをparamsに代入しておきます。
# paramsでの指定方法はAPIの作成者によって変わりますので、事前に確認しておく必要があります。

REQUEST_URL = 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426' 
APP_ID = "1034235205250283151"

params = {
    "format":"json",
    "largeClassCode": "japan",
    "middleClassCode":"okinawa",
    "smallClassCode":"nahashi",
    "applicationId":APP_ID
}


# アクセス先と認証と要求するデータの内容を指定出来たので、requestsのgetメソッドを使ってアクセスします。
# その結果をresに代入します。

res = requests.get(REQUEST_URL, params)

# 欲しいデータはresのjsonに格納されているので、res.json()をresultに代入しておきましょう。
# これでAPIで取得したデータはresultに代入されます。

result = res.json()

# %%
# 実際にresultに格納されたデータを見てみましょう。

# %% [markdown]
# ブラウザでもrequestsがアクセスしてる先をブラウザでも見てみましょう

# %%
# requestsがどんなURLでリクエストしたかをres.urlで確認出来ます。
res.url
# Out:
# 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?format=json&largeClassCode=japan&middleClassCode=okinawa&smallClassCode=nahashi&applicationId=1034235205250283151'

# %% [markdown]
# res.urlで出力したURLを整理してみると
#
# https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?
# format=json
# &largeClassCode=japan
# &middleClassCode=okinawa
# &smallClassCode=nahashi
# &applicationId=1011509919335500197
#
# となり、?の後ろ側にリクエストしたいパラメーターがついている事がわかります。

# %% [markdown]
# これは楽天トラベルに書いてある
#
# https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?
# applicationId=[アプリID]
# &format=xml
# &largeClassCode=japan
# &middleClassCode=akita
# &smallClassCode=tazawa
#
# と要求してるパラメータの順番が違うだけで、同じ事を要求の仕方をしているのがわかると思います！
#
# requestでは?の後ろのパラメータを

# %%
# paramの設定

params = {
    "format":"json",
    "largeClassCode": "japan",
    "middleClassCode":"akita",
    "smallClassCode":"tazawa",
    "applicationId":APP_ID
}

# %%
res.url
# Out:
# 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?format=json&largeClassCode=japan&middleClassCode=okinawa&smallClassCode=nahashi&applicationId=1034235205250283151'

# %% [markdown]
# という形で格納し、requests.get(REQUEST_URL, params)で１つのリクエスト付きURLにしています。

# %% [markdown]
# よってURLの後ろにあるパラメータとrequestsのparamsが同じ変数を指定している事がわかりますね！
#
# URL属性以外にもrequests.Responseクラスには以下のような属性がある（一部）。

# %% [markdown]
# | 属性 | 説明 |
# | --- | --- |
# | text | レスポンスの内容（content属性）を文字列にデコードしたもの |
# | content | レスポントの内容（バイト列）。テキスト表現ではなくバイナリデータを扱うときにはこちらを使用する |
# | encoding | content属性をtext属性にデコードする際に使用したエンコーディング |
# | apparent_encoding | https://pypi.org/project/charset-normalizer/もしくはhttps://pypi.org/project/chardet/によって推測されたエンコーディング。encoding属性の値とapparent_encoding属性の値が異なることもある |
# | headers | レスポンスヘッダーを大文字小文字の区別をしない辞書の形式で格納したもの |
# | url | リクエストしたURL。リダイレクトが発生した場合には、リダイレクト先のURL |
# | history | get関数でリクエストしたURLがリダイレクトされた場合に、リダイレクトされた結果を示すrequests.Responseクラスのインスタンスを古いものから順に並べたリスト |
# |  |  |

# %% [markdown]
# requests.Responseクラスのインスタンスが持つ属性（一部）
# 参照：https://atmarkit.itmedia.co.jp/ait/articles/2209/27/news035.html

# %% [markdown]
# では、http経由でデータを取得する所から演習しましょう。

# %% [markdown]
# ### 3.3.http経由でデータを取得

# %% [markdown]
# #### http通信のリクエストをしてみよう

# %% [markdown]
# リクエストをするためのライブラリをインポートしておきましょう！

# %%
#ライブラリrequestsを使うためにimportすることで機能を使う事が出来ます。

import requests

# %% [markdown]
# インポートすることによってrequestsの機能を使う事ができます。
# ではrequestsを使って、ブラウザのようにhtmlが取得できるかどうか確認してみましょう！
# requests.get("ここに接続したいサイトのURL")とすることでhtmlが取得できます。

# %% [markdown]
# <img src="img/img025.png">

# %% [markdown]
# 参照：https://www.itmanage.co.jp/column/about-http-https/

# %% [markdown]
# ブラウザと同じように取得できているかどうかは、ブラウザの検証機能にある、ページソース表示で確認できます！

# %%
#アクセスして取得したサイトデータをresに代入しておきます。今回はTech0のサイトにアクセス

res = requests.get("https://tech0-jp.com")

# %%
#resに代入しておいたサイトデータprintでかくにんします。

#これを得られた結果とブラウザのページソース表示で得られるhtmlを比較して、ブラウザと同じ機能であることを確認しましょう！

# %% [markdown]
# #### 楽天からデータを取得してみましょう

# %% [markdown]
# 楽天側が用意した仕様に沿ったアクセス先とリクエストパラメータを設定していきましょう！
# アクセス先とAPIキーとパラメーターを設定します

# %%
# アクセス先と認証IDと要求するデータを指定します。

REQUEST_URL = 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426' 
APP_ID = "1034235205250283151"

# %%
# param

params = {
    "format":"json",
    "largeClassCode": "japan",
    "middleClassCode":"akita",
    "smallClassCode":"tazawa",
    "applicationId":APP_ID
}

# %% [markdown]
# requests.get(アクセス先, リクエストパラメータ)を指定して、APIサーバーにデーターを要求しましょう！

# %%
# resにリクエストして得られた結果を代入します。
res = requests.get(REQUEST_URL, params)
res.encoding
res
print(res)
# Out:
# <Response [200]>

# %% [markdown]
# リクエストが成功したか、ステータスの数字で確認しましょう！
# - 200なら正常に通信完了
# - 404ならアクセス先が間違えています。
# - その他の400番台はパラメータが間違えています！

# %%
#変数だけを指定する事でprint()を省略できます。

# %% [markdown]
# 通信の結果、返ってきたデータの中身を変数resultにjsonとして格納してから確認してみましょう！
# res.json()とすることで、レスポンスデータの中にあるjsonデータをしてすることができます。

# %%
# resultにresの中にあるjsonデータを代入します。
result = res.json()

# 代入したデータを見てみましょう。
result
# Out:
# {'pagingInfo': {'recordCount': 75,
#   'pageCount': 3,
#   'page': 1,
#   'first': 1,
#   'last': 30},
#  'hotels': [{'hotel': [{'hotelBasicInfo': {'hotelNo': 4624,
#       'hotelName': '天然温泉\u3000田沢湖レイクリゾート',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=4624',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=4624&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=4624',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=4624',
#       'hotelKanaName': 'てんねんおんせん\u3000たざわこれいくりぞーと',
#       'hotelSpecial': '水深日本一の田沢湖の近く、スキー場・グラウンド・ゴルフ場認定コースあり',
#       'hotelMinCharge': 5060,
#       'latitude': 143059.23,
#       'longitude': 506645.02,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内字下高野82-117',
#       'telephoneNo': '0187-46-2016',
#       'faxNo': '0187-46-2241',
#       'access': 'JR秋田新幹線田沢湖駅からバスで２０分、盛岡Ｉ．Ｃから５０分。田沢湖駅から送迎バスにて約15分（要事前予約）',
#       'parkingInformation': '有り\u3000５００台\u3000無料',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/4624/4624.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/4624.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/4624/4624_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/4624.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/4624/4624map.gif',
#       'reviewCount': 1448,
#       'reviewAverage': 4.1,
#       'userReview': '露天風呂が利用でかなかったのが残念でした。部屋はきれいで気持ち良ったです。\u30002023-10-14 17:34:45投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.97,
#       'locationAverage': 3.87,
#       'roomAverage': 3.86,
#       'equipmentAverage': 3.94,
#       'bathAverage': 4.03,
#       'mealAverage': 4.19}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 15408,
#       'hotelName': '日本の山岳温泉リゾート\u3000新玉川温泉',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=15408',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=15408&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=15408',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=15408',
#       'hotelKanaName': 'にほんの山岳おんせんりぞーと\u3000しんたまがわおんせん',
#       'hotelSpecial': '強酸性日本一と言われる玉川温泉の源泉をそのまま掛け流し！',
#       'hotelMinCharge': 12100,
#       'latitude': 143854.53,
#       'longitude': 506597.74,
#       'postalCode': '014-1205',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖玉川',
#       'telephoneNo': '0187-58-3100',
#       'faxNo': '0187-58-3011',
#       'access': 'カーナビを設定の場合、電話0187-58-3100でお願いします。',
#       'parkingInformation': '有り（無料）。\u3000冬期間は田沢湖駅近くに無料駐車場有り。ご利用の際は、お問い合せ下さい。',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/15408/15408.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/15408.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/15408/15408_wa.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/15408.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/15408/15408map.gif',
#       'reviewCount': 1006,
#       'reviewAverage': 4.39,
#       'userReview': '昨年同時期に初めて伺い妻と又行きたいよね！って行ってたときに土日の現場がリスケになり急遽検索したら2部屋空いてましたので速攻で予約、事後報告で妻に言ったら喜んでくれました。（10/2の妻の誕生日を忘れ…\u30002023-10-13 13:27:26投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=15408" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.06,
#       'locationAverage': 4.06,
#       'roomAverage': 4.15,
#       'equipmentAverage': 3.86,
#       'bathAverage': 4.81,
#       'mealAverage': 3.92}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 14338,
#       'hotelName': '効能溢れる癒しの湯治宿\u3000玉川温泉',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=14338',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=14338&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=14338',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=14338',
#       'hotelKanaName': 'たまがわおんせん',
#       'hotelSpecial': '日帰り入浴は午前9:00〜午後3:30までです。',
#       'hotelMinCharge': 5170,
#       'latitude': 143858.55,
#       'longitude': 506619.2,
#       'postalCode': '014-1205',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖玉川渋黒沢国有林第3014林班ロ小班',
#       'telephoneNo': '0187-58-3000',
#       'faxNo': '0187-58-3011',
#       'access': 'JR田沢湖駅前から路線バスで約70分。お車でお越しの場合盛岡IC～田沢湖経由で約100分。',
#       'parkingInformation': '宿から5分ほど離れた場所にあります。当日係がご案内致します。',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/14338/14338.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/14338.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/14338/14338_bath1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/14338.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/14338/14338map.gif',
#       'reviewCount': 584,
#       'reviewAverage': 4.43,
#       'userReview': '温泉は最高で雰囲も気最高でした。\u30002023-10-14 11:53:12投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.98,
#       'locationAverage': 4.07,
#       'roomAverage': 3.68,
#       'equipmentAverage': 3.67,
#       'bathAverage': 4.81,
#       'mealAverage': 3.91}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 70699,
#       'hotelName': 'ホテルルートイン\u3000大曲駅前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=70699',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=70699&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=70699',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=70699',
#       'hotelKanaName': 'るーといん\u3000おおまがりえきまえ',
#       'hotelSpecial': 'ＷＯＷＯＷ全室で無料視聴可■VODルームシアター無料視聴可能（一般映画のみ）（コンフォート特典）',
#       'hotelMinCharge': 5125,
#       'latitude': 142062.57,
#       'longitude': 505737.26,
#       'postalCode': '014-0027',
#       'address1': '秋田県',
#       'address2': '大仙市大曲通町3-14',
#       'telephoneNo': '0187-86-3511',
#       'faxNo': '0187-86-3522',
#       'access': 'ＪＲ秋田新幹線大曲駅より徒歩３分/大曲I.Cより車で約10分/秋田市より秋田自動車道利用で約40分',
#       'parkingInformation': '有り\u3000７０台\u3000無料\u3000予約不要 先着順  ※満車の際は近隣駐車場をご案内致します｡',
#       'nearestStation': '大曲（秋田）',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/70699/70699.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/70699.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/70699/70699_tt.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/70699.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/70699/70699map.gif',
#       'reviewCount': 1204,
#       'reviewAverage': 4.09,
#       'userReview': '楽天から予約時、2名予約のため禁煙、喫煙の区別ができず、喫煙を予約し、コメントに1名禁煙希望と書き込みました。その後、ホテルに電話をし、禁煙で承っていると確認にしたもかかわらず、当日は喫煙ルーム。満室…\u30002023-10-11 18:12:37投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=70699" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.03,
#       'locationAverage': 4.64,
#       'roomAverage': 4,
#       'equipmentAverage': 3.86,
#       'bathAverage': 3.83,
#       'mealAverage': 3.76}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 11222,
#       'hotelName': '亀の井ホテル\u3000田沢湖',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=11222',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=11222&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=11222',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=11222',
#       'hotelKanaName': 'かめのいほてる たざわこ',
#       'hotelSpecial': '2023年10月1日より「亀の井ホテル 田沢湖」へリブランドいたしました。',
#       'hotelMinCharge': 4200,
#       'latitude': 143205.33,
#       'longitude': 506768.68,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内駒ケ岳2-32',
#       'telephoneNo': '0187-46-2131',
#       'faxNo': '0187-46-2552',
#       'access': 'JR田沢湖駅より乳頭温泉行バス約35分「杉谷湖」下車/盛岡ICより約1時間\u3000駒ケ岳八合目登山口行きバス停まで徒歩約10分',
#       'parkingInformation': '有り\u3000100台\u3000無料\u3000先着順',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/11222/11222.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/11222.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/11222/11222_war.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/11222.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/11222/11222map.gif',
#       'reviewCount': 870,
#       'reviewAverage': 3.86,
#       'userReview': '食事、部屋と大変満足して子供もまた泊まりに行きたいと言ってました。1つだけ残念だったのはチェックイン時には露天風呂は機械的な問題で使用不可ですと案内されましたが、その後露天風呂への通路が通れるよう…\u30002023-10-08 11:47:36投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=11222" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.72,
#       'locationAverage': 3.84,
#       'roomAverage': 3.53,
#       'equipmentAverage': 3.51,
#       'bathAverage': 3.87,
#       'mealAverage': 3.94}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 162983,
#       'hotelName': 'リバーサイドホテル大曲',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=162983',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=162983&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=162983',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=162983',
#       'hotelKanaName': 'りばーさいどほてるおおまがり',
#       'hotelSpecial': '【２０１７年８月 リニューアルオープン！！】 日本一の花火の街、大曲のビジネス・観光の新拠点♪',
#       'hotelMinCharge': 4500,
#       'latitude': 142048.69,
#       'longitude': 505742.11,
#       'postalCode': '014-0024',
#       'address1': '秋田県',
#       'address2': '大仙市大曲中通町2-20',
#       'telephoneNo': '0187-62-0115',
#       'faxNo': '0187-62-0153',
#       'access': '大曲駅より徒歩約7分 秋田自動車道大曲ＩＣより約15分',
#       'parkingInformation': '18台の無料駐車場有り（先着順となります）※満車の際は近隣の駐車場をご案内致します。',
#       'nearestStation': '大曲（秋田）',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/162983/162983.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/162983.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/162983/162983_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/162983.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/162983/162983map.gif',
#       'reviewCount': 286,
#       'reviewAverage': 3.78,
#       'userReview': '１泊２食付きで、このお値段なら満足です。ご飯のおかわりが自由なのも、ハラペコにはグッド。近くにスーパーがあり、お酒にも困りません。\u30002023-10-14 00:37:27投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.69,
#       'locationAverage': 3.91,
#       'roomAverage': 3.58,
#       'equipmentAverage': 3.44,
#       'bathAverage': 3.26,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 161208,
#       'hotelName': '町家ホテル角館',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=161208',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=161208&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=161208',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=161208',
#       'hotelKanaName': 'まちやほてるかくのだて',
#       'hotelSpecial': '小京都角館にマッチした和風でモダンなホテル。武家屋敷通りまで徒歩２分・観光やビジネスにも最適なホテル',
#       'hotelMinCharge': 7480,
#       'latitude': 142533.62,
#       'longitude': 506035.87,
#       'postalCode': '014-0322',
#       'address1': '秋田県',
#       'address2': '仙北市角館町七日町1-1',
#       'telephoneNo': '0187-55-2001',
#       'faxNo': '0187-55-2221',
#       'access': 'ＪＲ\u3000角館駅より徒歩約15分。お車にて約３分。田沢湖周辺までは車で20分\u3000大曲周辺車で30分\u3000秋田市迄は約1時間',
#       'parkingInformation': '有り\u300025台\u3000無料\u3000',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/161208/161208.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/161208.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/161208/161208_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/161208.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/161208/161208map.gif',
#       'reviewCount': 253,
#       'reviewAverage': 4.33,
#       'userReview': '９月２２日に宿泊しました。近くに温泉もあり良かったです。\u30002023-09-30 10:26:59投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.07,
#       'locationAverage': 4.52,
#       'roomAverage': 4.3,
#       'equipmentAverage': 3.88,
#       'bathAverage': 3.62,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 72803,
#       'hotelName': '休暇村\u3000乳頭温泉郷',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=72803',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=72803&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=72803',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=72803',
#       'hotelKanaName': 'きゅうかむら\u3000にゅうとうおんせんぎょう',
#       'hotelSpecial': '美しいブナ林に囲まれた静かな宿です。温泉浴や森林浴が楽しめ、ここでは時間がゆっくりと流れています。',
#       'hotelMinCharge': 15500,
#       'latitude': 143273.15,
#       'longitude': 506873.49,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内駒ヶ岳2-1',
#       'telephoneNo': '0187-46-2244',
#       'faxNo': '0187-46-2700',
#       'access': 'ＪＲ\u3000田沢湖駅より羽後交通乳頭温泉行「休暇村」下車、徒歩０分',
#       'parkingInformation': '有り\u3000１００台\u3000無料\u3000予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/72803/72803.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/72803.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/72803/72803_wa.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/72803.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/72803/72803map.gif',
#       'reviewCount': 394,
#       'reviewAverage': 4.55,
#       'userReview': '3月24日に宿泊しました。お風呂とお食事が素晴らしかったです。また、利用したい宿です。\u30002023-09-26 17:56:13投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.2,
#       'locationAverage': 4.25,
#       'roomAverage': 4.3,
#       'equipmentAverage': 4.07,
#       'bathAverage': 4.7,
#       'mealAverage': 4.62}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 145044,
#       'hotelName': '大曲シティホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=145044',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=145044&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=145044',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=145044',
#       'hotelKanaName': 'おおまがりしてぃほてる',
#       'hotelSpecial': '立地良好',
#       'hotelMinCharge': 2750,
#       'latitude': 142065.11,
#       'longitude': 505719.71,
#       'postalCode': '014-0014',
#       'address1': '秋田県',
#       'address2': '大仙市大曲福住町5-15',
#       'telephoneNo': '080 3978 6836',
#       'faxNo': '0187-73-5950',
#       'access': 'ＪＲ\u3000大曲駅より徒歩にて５分',
#       'parkingInformation': '徒歩５分のところにあり\u3000台数限りあり\u3000先着順\u3000２トン車まで \u3000春、夏花火前後のは利用できません。',
#       'nearestStation': '大曲（秋田）',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/145044/145044.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/145044.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/145044/145044map.gif',
#       'reviewCount': 427,
#       'reviewAverage': 2.38,
#       'userReview': '簡易シャワーとは書いてあったがトイレにシャワーが付いているなかなかすごい部屋も古いなるべく安く泊まりたいならよいのでは\u30002023-10-11 18:08:04投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 2.68,
#       'locationAverage': 3.55,
#       'roomAverage': 2.17,
#       'equipmentAverage': 2.32,
#       'bathAverage': 1.87,
#       'mealAverage': 2.85}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 10867,
#       'hotelName': 'グリーンホテル大曲',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=10867',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=10867&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=10867',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=10867',
#       'hotelKanaName': 'ぐりーんほてる\u3000おおまがり',
#       'hotelSpecial': 'ビジネス、観光に便利なＪＲ大曲駅西口徒歩3分・全室インターネット接続可能（無線LAN)',
#       'hotelMinCharge': 4250,
#       'latitude': 142068.59,
#       'longitude': 505726.93,
#       'postalCode': '014-0013',
#       'address1': '秋田県',
#       'address2': '大仙市朝日町18-1',
#       'telephoneNo': '0187-86-3333',
#       'faxNo': '0187-86-3020',
#       'access': 'ＪＲ大曲駅より徒歩3分／秋田自動車道大曲ＩＣより１０分／秋田空港より秋田自動車道経由約５０分',
#       'parkingInformation': '有り\u3000８０台\u3000先着順\u3000無料',
#       'nearestStation': '大曲（秋田）',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/10867/10867.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/10867.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/10867/10867_heya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/10867.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/10867/10867map.gif',
#       'reviewCount': 1198,
#       'reviewAverage': 3.93,
#       'userReview': '急用ができたので一泊追加できて助かりました。ただ前日までの部屋から端の部屋に移ったらWi-Fiが使えませんでした。そのむねを伝えたところルーターを貸してもらえました。宿泊費も安いうえ設備も…\u30002023-10-13 09:28:17投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=10867" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.77,
#       'locationAverage': 3.95,
#       'roomAverage': 3.74,
#       'equipmentAverage': 3.7,
#       'bathAverage': 3.8,
#       'mealAverage': 3.8}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 107856,
#       'hotelName': '田町武家屋敷ホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=107856',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=107856&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=107856',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=107856',
#       'hotelKanaName': 'たまちぶけやしきほてる',
#       'hotelSpecial': '小京都角館に佇む黒板塀に囲まれた蔵造の宿。民芸調の客室と、創作料理がお楽しみいただけます。',
#       'hotelMinCharge': 10230,
#       'latitude': 142518.36,
#       'longitude': 506045.36,
#       'postalCode': '014-0312',
#       'address1': '秋田県',
#       'address2': '仙北市角館町田町下丁23',
#       'telephoneNo': '0187-52-1700',
#       'faxNo': '0187-52-1701',
#       'access': '角館駅から徒歩で１５分',
#       'parkingInformation': '有り\u3000９台\u3000無料\u3000予約不要',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107856/107856.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/107856.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107856/107856_yst.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/107856.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107856/107856map.gif',
#       'reviewCount': 141,
#       'reviewAverage': 4.64,
#       'userReview': '（週末の大雨対応お疲れさまですm(_ _)m）早めの到着になりましたが、部屋の準備を早めていただき、すぐにチェックインでき助かりました。お部屋は木の香りを感じる落ち着いた和風の色調で、とても良かったで…\u30002023-07-17 12:58:30投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=107856" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.55,
#       'locationAverage': 4.41,
#       'roomAverage': 4.41,
#       'equipmentAverage': 4,
#       'bathAverage': 3.6,
#       'mealAverage': 4.62}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 20646,
#       'hotelName': 'Ｔａｂｉｓｔ\u3000ホテル富士',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=20646',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=20646&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=20646',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=20646',
#       'hotelKanaName': 'たびすと\u3000ほてるふじ',
#       'hotelSpecial': '【全室和室LAN完備】【大曲駅徒歩3分】【コンビニ徒歩5分】【秋田米おいしい朝食】',
#       'hotelMinCharge': 3300,
#       'latitude': 142061.15,
#       'longitude': 505733.82,
#       'postalCode': '014-0027',
#       'address1': '秋田県',
#       'address2': '大仙市通町1-28',
#       'telephoneNo': '0187-62-0243',
#       'faxNo': '0187-62-4140',
#       'access': 'ＪＲ大曲駅～徒歩３分／秋田自動車道・大曲ＩＣ～１０分',
#       'parkingInformation': '有り\u3000２０台\u3000無料\u3000先着順',
#       'nearestStation': '大曲（秋田）',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/20646/20646.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/20646.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/20646/20646_heya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/20646.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/20646/20646map.gif',
#       'reviewCount': 436,
#       'reviewAverage': 3.95,
#       'userReview': '朝食は美味しいです。現在、夕食がないのが残念でした。部屋に関しては布団式で値段の割りには良いと思います。バスはシャワーとしてしか使えないですね。\u30002023-10-13 09:14:27投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.68,
#       'locationAverage': 4.68,
#       'roomAverage': 3.81,
#       'equipmentAverage': 3.38,
#       'bathAverage': 2.81,
#       'mealAverage': 4}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 139459,
#       'hotelName': '花心亭しらはま',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=139459',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=139459&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=139459',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=139459',
#       'hotelKanaName': 'かしんていしらはま',
#       'hotelSpecial': '＜全室専用ダイニングルーム付き客室＞田沢湖畔に望み、秋田の風土とこだわりぬいた郷土懐石を愉しむ宿。',
#       'hotelMinCharge': 21500,
#       'latitude': 143032.59,
#       'longitude': 506525.84,
#       'postalCode': '014-1204',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖田沢春山145-15',
#       'telephoneNo': '0187-43-0436',
#       'faxNo': '0187-43-3822',
#       'access': '田沢湖駅からお車で約１２分',
#       'parkingInformation': '有り\u3000３０台\u3000無料\u3000予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/139459/139459.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/139459.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/139459/139459_rm1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/139459.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/139459/139459map.gif',
#       'reviewCount': 84,
#       'reviewAverage': 4.44,
#       'userReview': 'おもてなしと食事が最高でした。丁寧な接客に知りたい情報を詳しく教えていただき、旅行をより楽しめました。食事は様々な食材を使った手の込んだ料理で、目でも舌でも楽しめました。\u30002023-09-23 22:12:54投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.39,
#       'locationAverage': 4.33,
#       'roomAverage': 4.61,
#       'equipmentAverage': 4.39,
#       'bathAverage': 4.06,
#       'mealAverage': 4.72}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 70772,
#       'hotelName': '田沢湖水沢温泉郷セルリアンリゾートＡＯＮＩ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=70772',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=70772&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=70772',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=70772',
#       'hotelKanaName': 'たざわこみずさわおんせんきょうせるりあんりぞーとあおに',
#       'hotelSpecial': '★2023年リブランド！美肌成分たっぷりの源泉かけ流しの露天風呂付き大浴場と地元食材の料理が好評',
#       'hotelMinCharge': 8000,
#       'latitude': 143142.65,
#       'longitude': 506721.72,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内下高野73-13',
#       'telephoneNo': '0187-46-2006',
#       'faxNo': '0187-46-2776',
#       'access': '田沢湖駅よりバスで約２５分（乳頭線、水沢温泉郷で降車）、タクシーで約１５分',
#       'parkingInformation': '無料／40台／予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/70772/70772.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/70772.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/70772/70772_meal.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/70772.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/70772/70772map.gif',
#       'reviewCount': 236,
#       'reviewAverage': 4.11,
#       'userReview': '温泉に湯の華ではなく汚れが浮いていてがっかりでした。特に露天は脚を入れる気にならないほどでした。\u30002023-10-11 18:17:24投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.16,
#       'locationAverage': 3.97,
#       'roomAverage': 3.89,
#       'equipmentAverage': 3.82,
#       'bathAverage': 4,
#       'mealAverage': 4.03}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 1720,
#       'hotelName': 'ホテルフォルクローロ角館＜JR東日本ホテルズ＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=1720',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=1720&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=1720',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=1720',
#       'hotelKanaName': 'ふぉるくろーろ\u3000かくのだて',
#       'hotelSpecial': '秋田新幹線「角館駅」となり♪武家屋敷通りまで徒歩圏内☆田沢湖駅までひと駅 全室Wi-Fi',
#       'hotelMinCharge': 5450,
#       'latitude': 142518.61,
#       'longitude': 506066.98,
#       'postalCode': '014-0368',
#       'address1': '秋田県',
#       'address2': '仙北市角館町中管沢14',
#       'telephoneNo': '0187-53-2070',
#       'faxNo': '0187-53-2118',
#       'access': 'ＪＲ角館駅隣接\u3000秋田空港から車で４５分 \u3000東北自動車道盛岡IC～６０分 秋田自動車道大曲IC～40分 \u3000',
#       'parkingInformation': '有り\u3000１２台\u3000無料\u3000(満車の場合は近隣の無料駐車場にご案内）',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/1720/1720.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/1720.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/1720/1720_twn.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/1720.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/1720/1720map.gif',
#       'reviewCount': 668,
#       'reviewAverage': 4.17,
#       'userReview': '近隣のホテルも空きがなく探していたらちょうどこちらが空いていて立地がよく助かりました。快適に過ごせました。\u30002023-09-19 16:24:24投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.1,
#       'locationAverage': 4.71,
#       'roomAverage': 4.12,
#       'equipmentAverage': 3.88,
#       'bathAverage': 3.59,
#       'mealAverage': 3.53}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 5576,
#       'hotelName': 'あきた芸術村\u3000温泉ゆぽぽ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=5576',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=5576&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=5576',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=5576',
#       'hotelKanaName': 'たざわこげいじゅつむら\u3000おんせんゆぽぽ',
#       'hotelSpecial': 'わらび劇場にてミュージカルや工芸館で陶芸体験などをお楽しみ頂けます。',
#       'hotelMinCharge': 6050,
#       'latitude': 142589.21,
#       'longitude': 506251.81,
#       'postalCode': '014-1192',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖卒田字早稲田430',
#       'telephoneNo': '0187-44-3333',
#       'faxNo': '0187-44-3334',
#       'access': 'JR「秋田新幹線こまち」角館駅より車で７分\u3000事前予約でシャトルバスもご利用頂けます',
#       'parkingInformation': '有り\u3000２００台\u3000無料\u3000先着順',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/5576/5576.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/5576.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/5576/5576_twn.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/5576.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/5576/5576map.gif',
#       'reviewCount': 392,
#       'reviewAverage': 4.59,
#       'userReview': 'ゆったりとした広いお部屋と、気持ちの良い大浴場で、とてもくつろげました。スタッフの方も皆さん親切で、心配りにも感動しました。今回は遅い到着となってしまい見損ねてしまったわらび座の出し物…\u30002023-09-21 11:07:30投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=5576" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.43,
#       'locationAverage': 3.98,
#       'roomAverage': 4.22,
#       'equipmentAverage': 4.04,
#       'bathAverage': 4.28,
#       'mealAverage': 4.59}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 5387,
#       'hotelName': '心に和みが灯る宿\u3000水沢温泉郷\u3000青荷山荘',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=5387',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=5387&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=5387',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=5387',
#       'hotelKanaName': 'こころになごみがともるやど\u3000みずさわおんせんきょう\u3000あおにさんそう',
#       'hotelSpecial': '秋田竿燈まつりをコンセプトに2021年全室リニューアル！貸切天然温泉と地元食材の料理が好評',
#       'hotelMinCharge': 10000,
#       'latitude': 143143.41,
#       'longitude': 506722.79,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内下高野７３－１４',
#       'telephoneNo': '0187-46-2256',
#       'faxNo': '0187-46-2725',
#       'access': '車以外／JR秋田新幹線田沢湖駅より乳頭温泉行バスで水沢温泉郷下車。車／東北自動車道盛岡IC～国道46号線を秋田方面へ。',
#       'parkingInformation': '【あり】無料／１6台まで／予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/5387/5387.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/5387.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/5387/5387_heya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/5387.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/5387/5387map.gif',
#       'reviewCount': 213,
#       'reviewAverage': 4.09,
#       'userReview': 'ゆっくり休むことができました料理も美味しかったですが鍋料理だけ、味が濃すぎましたそれが残念です\u30002023-10-07 16:16:07投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.83,
#       'locationAverage': 4.04,
#       'roomAverage': 4.17,
#       'equipmentAverage': 3.83,
#       'bathAverage': 3.65,
#       'mealAverage': 4.43}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 13886,
#       'hotelName': '大曲エンパイヤホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=13886',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=13886&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=13886',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=13886',
#       'hotelKanaName': 'おおまがり\u3000えんぱいやほてる',
#       'hotelSpecial': '【17時〜19時半レストラン利用で1ドリンクサービス】大曲駅から徒歩8分／無料駐車場／朝食個別配膳',
#       'hotelMinCharge': 5775,
#       'latitude': 142069.42,
#       'longitude': 505713.99,
#       'postalCode': '014-0015',
#       'address1': '秋田県',
#       'address2': '大仙市大曲白金町8-17',
#       'telephoneNo': '0187-63-1131',
#       'faxNo': '0187-63-5277',
#       'access': 'JR奥羽本線・田沢湖線・秋田新幹線「大曲駅」より徒歩８分 / 秋田自動車道 大曲ICより市内へ車で15分、立地も最高★',
#       'parkingInformation': '有り\u3000７０台\u3000無料\u3000先着順',
#       'nearestStation': '大曲（秋田）',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/13886/13886.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/13886.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/13886/13886_you.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/13886.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/13886/13886map.gif',
#       'reviewCount': 393,
#       'reviewAverage': 3.52,
#       'userReview': 'アメニティが有料は初めて\u30002023-10-03 12:34:38投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.48,
#       'locationAverage': 3.52,
#       'roomAverage': 3.1,
#       'equipmentAverage': 2.81,
#       'bathAverage': 2.94,
#       'mealAverage': 3.69}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181765,
#       'hotelName': '川口温泉\u3000奥羽山荘',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181765',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181765&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181765',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181765',
#       'hotelKanaName': 'かわぐちおんせん\u3000おううさんそう',
#       'hotelSpecial': '原風景が広がる豊かな自然と抜群の開放感！ご家族やペットとゆっくり穏やかな時間を',
#       'hotelMinCharge': 6050,
#       'latitude': 142208.01,
#       'longitude': 506374.71,
#       'postalCode': '019-1613',
#       'address1': '秋田県',
#       'address2': '大仙市太田町太田字惣行大谷地10-5',
#       'telephoneNo': '0187-88-1717',
#       'faxNo': '0187-88-1726',
#       'access': '秋田空港より車で約60分、大曲I.Cより車で約30分、大曲駅より車で約25分、角館駅より車で約20分',
#       'parkingInformation': '有り\u3000150台\u3000無料\u3000予約不要',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181765/181765.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181765.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181765/181765map.gif',
#       'reviewCount': 60,
#       'reviewAverage': 4,
#       'userReview': '接客は丁寧で気持ちよかったです。食事は美味しく、オーナーが日本酒をサービスしてまわってました。お酒もとても美味しかったです。素泊まりではもったいないと思います、利用時は食事付きをお勧めします。\u30002023-10-10 18:04:03投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.88,
#       'locationAverage': 3.5,
#       'roomAverage': 3.63,
#       'equipmentAverage': 3.35,
#       'bathAverage': 4,
#       'mealAverage': 4.35}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 59623,
#       'hotelName': '乳頭温泉郷\u3000大釜温泉',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=59623',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=59623&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=59623',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=59623',
#       'hotelKanaName': 'おおがまおんせん',
#       'hotelSpecial': '温泉ファンをうならせる乳頭温泉は24時間入浴OK。露天・内湯ともに男女別。家庭的な山里料理に舌鼓。',
#       'hotelMinCharge': 11000,
#       'latitude': 143285.89,
#       'longitude': 506880.78,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内 先達国有林５０',
#       'telephoneNo': '0187-46-2438',
#       'faxNo': '0187-46-2436',
#       'access': '田沢湖駅よりバス羽後交通乳頭温泉郷行終点下車徒歩１分',
#       'parkingInformation': '有り\u3000３０台\u3000無料\u3000予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/59623/59623.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/59623.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/59623/59623_ky.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/59623.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/59623/59623map.gif',
#       'reviewCount': 355,
#       'reviewAverage': 3.43,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 3.4,
#       'locationAverage': 0,
#       'roomAverage': 3.13,
#       'equipmentAverage': 0,
#       'bathAverage': 3.87,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 129680,
#       'hotelName': 'ホテルグランド天空',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=129680',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=129680&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=129680',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=129680',
#       'hotelKanaName': 'ぐらんどてんくう',
#       'hotelSpecial': 'ブナ林に囲まれた田沢湖高原に佇む「ホテルグランド天空」は、全室から水深日本一の田沢湖が望めます',
#       'hotelMinCharge': 8500,
#       'latitude': 143206.45,
#       'longitude': 506755.79,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内駒ヶ岳2-16',
#       'telephoneNo': '0187-46-2004',
#       'faxNo': '0187-46-2526',
#       'access': 'ＪＲ\u3000田沢湖駅からバスで約36分\u3000乳頭行バスでアルパこまくさ停留所か次の上高原バス停',
#       'parkingInformation': '有り\u3000２５台\u3000無料\u3000予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/129680/129680.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/129680.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/129680/129680_was.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/129680.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/129680/129680map.gif',
#       'reviewCount': 237,
#       'reviewAverage': 4.17,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 107777,
#       'hotelName': '南玉川温泉\u3000湯宿\u3000はなやの森',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=107777',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=107777&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=107777',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=107777',
#       'hotelKanaName': 'みなみたまがわおんせん\u3000ゆやど\u3000はなやのもり',
#       'hotelSpecial': '秘境玉川宝仙湖に佇む「湯宿\u3000はなやの森」当館自慢の露天風呂付客室で、ごゆっくりお寛ぎくださいませ。',
#       'hotelMinCharge': 22000,
#       'latitude': 143465.09,
#       'longitude': 506415.46,
#       'postalCode': '014-1204',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖玉川328',
#       'telephoneNo': '0187-49-2700',
#       'faxNo': '0187-49-2711',
#       'access': '田沢湖駅よりお車で３０分',
#       'parkingInformation': '有',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107777/107777.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/107777.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107777/107777_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/107777.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/107777/107777map.gif',
#       'reviewCount': 109,
#       'reviewAverage': 3,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 16520,
#       'hotelName': '田沢湖高原温泉\u3000田沢高原ホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=16520',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=16520&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=16520',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16520',
#       'hotelKanaName': 'たざわここうげんおんせん\u3000たざわこうげんほてる',
#       'hotelSpecial': '家族で営む、山の温泉宿。\u3000施設は古くなってまいりましたが、ハードよりハートを大切にしております。',
#       'hotelMinCharge': 6050,
#       'latitude': 143194.32,
#       'longitude': 506755.24,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内駒ヶ岳2',
#       'telephoneNo': '0187-46-2311',
#       'faxNo': '0187-46-2846',
#       'access': '田沢湖駅前バスターミナルより高原温泉バス停下車、隣りになります。',
#       'parkingInformation': '有り\u300016台\u3000無料\u3000先着順',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16520/16520.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/16520.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16520/16520_w8.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/16520.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16520/16520map.gif',
#       'reviewCount': 253,
#       'reviewAverage': 4.63,
#       'userReview': '秋田駒ヶ岳登山の前泊で利用。田沢湖駅からのバス停が目の前で、なおかつ「アルパこまくさ」まで徒歩6〜7分と、アクセスは意外に便利です。正直、建物は全体的にかなり古く、傷みもそこそこ目立ちます。オート…\u30002023-09-18 01:47:50投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16520" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.74,
#       'locationAverage': 4.37,
#       'roomAverage': 3.79,
#       'equipmentAverage': 3.89,
#       'bathAverage': 4.37,
#       'mealAverage': 4.61}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 162793,
#       'hotelName': '湖畔浪漫の宿\u3000かたくりの花',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=162793',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=162793&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=162793',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=162793',
#       'hotelKanaName': 'こはんろまんのやど\u3000かたくりのはな',
#       'hotelSpecial': '田沢湖畔まで徒歩1分。湖を眺めるお部屋と無料展望貸切露天風呂。田沢湖の美しい景色を楽しむ癒しの空間',
#       'hotelMinCharge': 15840,
#       'latitude': 143034.41,
#       'longitude': 506523.18,
#       'postalCode': '014-1204',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖田沢春山197-15',
#       'telephoneNo': '0187-43-1200',
#       'faxNo': '0187-43-1203',
#       'access': 'ＪＲ\u3000田沢湖駅よりお車にて約１２分',
#       'parkingInformation': '有り\u3000無料\u3000予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/162793/162793.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/162793.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/162793/162793_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/162793.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/162793/162793map.gif',
#       'reviewCount': 16,
#       'reviewAverage': 3.9,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 141336,
#       'hotelName': '夏瀬温泉\u3000都わすれ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=141336',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=141336&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=141336',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=141336',
#       'hotelKanaName': 'なつせおんせん\u3000みやこわすれ',
#       'hotelSpecial': '江戸時代から薬湯として親しまれてきた秘湯、和と洋が融合したモダンジャパニーズの寛ぎの空間が待つ。',
#       'hotelMinCharge': 37350,
#       'latitude': 142658.1,
#       'longitude': 506542.63,
#       'postalCode': '014-1113',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖卒田夏瀬84',
#       'telephoneNo': '0187-44-2220',
#       'faxNo': '0187-44-2219',
#       'access': '角館駅よりお車にて約３０分（無料送迎車有り\u3000要予約）',
#       'parkingInformation': '有り\u3000３０台\u3000無料\u3000要予約',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/141336/141336.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/141336.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/141336/141336_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/141336.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/141336/141336map.gif',
#       'reviewCount': 61,
#       'reviewAverage': 4,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 128566,
#       'hotelName': '角館温泉\u3000花葉館',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=128566',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=128566&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=128566',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128566',
#       'hotelKanaName': 'かくのだておんせんかようかん',
#       'hotelSpecial': '角館美人を育む肌に優しい温泉を源泉かけ流しで！露天風呂、ミストサウナ、泡風呂など数種類楽しめる◎',
#       'hotelMinCharge': 7150,
#       'latitude': 142625.54,
#       'longitude': 505728.7,
#       'postalCode': '014-0344',
#       'address1': '秋田県',
#       'address2': '仙北市角館町西長野古米沢30-19',
#       'telephoneNo': '0187-55-5888',
#       'faxNo': '0187-53-3337',
#       'access': 'JR角館駅より車で20分（無料シャトルバス有り）',
#       'parkingInformation': '有り\u3000100台\u3000無料\u3000予約不要',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128566/128566.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/128566.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128566/128566_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/128566.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128566/128566map.gif',
#       'reviewCount': 79,
#       'reviewAverage': 4.19,
#       'userReview': '朝食バイキング、空になっても補充されずメインはほぼ空、残り物を頂きました\u30002023-10-03 12:35:48投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.56,
#       'locationAverage': 3.29,
#       'roomAverage': 4,
#       'equipmentAverage': 3.88,
#       'bathAverage': 4.25,
#       'mealAverage': 4.18}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 2763,
#       'hotelName': '田沢湖畔の小さなリゾート\u3000ペンションサウンズグッド！',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=2763',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=2763&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=2763',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=2763',
#       'hotelKanaName': 'たざわこはんのちいさなりぞーとぺんしょん\u3000さうんずぐっと',
#       'hotelSpecial': 'ジャズが流れる大人の隠れ家！第1土曜は生演奏♪ロフト造りのB&B☆北東北観光のベースキャンプ！',
#       'hotelMinCharge': 7370,
#       'latitude': 143073.63,
#       'longitude': 506470.01,
#       'postalCode': '014-1204',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖田沢字潟前160-58',
#       'telephoneNo': '0187-43-0127',
#       'faxNo': '0187-43-0578',
#       'access': 'JR秋田新幹線「たざわこ」駅からバス12分。東北自動車道「盛岡」ICから車で50分。',
#       'parkingInformation': '有10台\u3000無料',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/2763/2763.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/2763.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/2763/2763_bas.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/2763.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/2763/2763map.gif',
#       'reviewCount': 194,
#       'reviewAverage': 4.67,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 147002,
#       'hotelName': 'かくのだて温泉\u3000町宿\u3000ねこの鈴',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=147002',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=147002&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=147002',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=147002',
#       'hotelKanaName': 'かくのだておんせん\u3000まちやど\u3000ねこのすず',
#       'hotelSpecial': '【源泉かけ流し天然温泉】角館駅から一番近い宿。隣接の「土間人」で秋田料理も味わえる★',
#       'hotelMinCharge': 6600,
#       'latitude': 142523.09,
#       'longitude': 506038.33,
#       'postalCode': '014-0317',
#       'address1': '秋田県',
#       'address2': '仙北市角館町下中町28',
#       'telephoneNo': '0187-42-8105',
#       'faxNo': '0187-52-2223',
#       'access': 'JR角館駅より徒歩10分／大曲ICよりお車で30分／協和ICよりお車で30分',
#       'parkingInformation': '有り\u30005台\u3000無料\u3000要予約',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/147002/147002.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/147002.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/147002/147002_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/147002.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/147002/147002map.gif',
#       'reviewCount': 73,
#       'reviewAverage': 4,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 44352,
#       'hotelName': '民宿\u3000惣之助',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=44352',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=44352&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=44352',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=44352',
#       'hotelKanaName': 'そうのすけ',
#       'hotelSpecial': '閑静な環境、季節折々の山菜、自家栽培の有機野菜、自慢の“あきたこまち”と化石の宿です。長期滞在歓迎。',
#       'hotelMinCharge': 7000,
#       'latitude': 143029.12,
#       'longitude': 506571.54,
#       'postalCode': '014-1201',
#       'address1': '秋田県',
#       'address2': '仙北市田沢湖生保内字阿気128',
#       'telephoneNo': '0187-43-2161',
#       'faxNo': '0187-43-2161',
#       'access': '田沢湖駅より車で１０分',
#       'parkingInformation': '有り\u3000１０台\u3000無料\u3000予約不要',
#       'nearestStation': '田沢湖',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/44352/44352.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/44352.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/44352/44352map.gif',
#       'reviewCount': 45,
#       'reviewAverage': 4.55,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178536,
#       'hotelName': '和のゐ角館',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178536',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178536&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178536',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178536',
#       'hotelKanaName': 'わのいかくのだて',
#       'hotelSpecial': '「角館古民家ホテル」は、武家屋敷で有名な小京都「角館」の歴史ある蔵を改装したホテルです。',
#       'hotelMinCharge': 14500,
#       'latitude': 142524.63,
#       'longitude': 506045.63,
#       'postalCode': '014-0368',
#       'address1': '秋田県',
#       'address2': '仙北市角館町中菅沢14',
#       'telephoneNo': '0187-53-2774',
#       'faxNo': '0187-53-2118',
#       'access': '「和のゐ角館フロントカウンター」は「ホテルフォルクローロ角館」の中にございます。【角館駅より徒歩にて約１分】',
#       'parkingInformation': '有り\u3000無料\u3000予約不要',
#       'nearestStation': '角館',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178536/178536.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178536.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178536/178536_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/178536.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178536/178536map.gif',
#       'reviewCount': 18,
#       'reviewAverage': 4.25,
#       'userReview': None}},
#     {'hotelRatingInfo': {'serviceAverage': 0,
#       'locationAverage': 0,
#       'roomAverage': 0,
#       'equipmentAverage': 0,
#       'bathAverage': 0,
#       'mealAverage': 0}}]}]}

# %% [markdown]
# ## 4.全体像：取得したデータをエクセルのように扱う

# %% [markdown]
# ### 4.1.実際にやる事

# %% [markdown]
# APIから得られたjsonで得られたデータを確認します。
# jsonだと人間にはわかりずらく、データ加工が難しいため、pandasを使ってエクセルのように変換します。

# %%
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']['hotelName']　を変数を扱う事で、どのホテルのデータでも見れるようにしましょう。
# i = 0として１つ目のホテルの情報を見てみましょう。

# printで表示

i = 0
print(result["hotels"][i]["hotel"][0]["hotelBasicInfo"]["hotelName"])
print(result["hotels"][i]["hotel"][0]["hotelBasicInfo"]["planListUrl"])
print(result["hotels"][i]["hotel"][0]["hotelBasicInfo"]["hotelMinCharge"])
print(result["hotels"][i]["hotel"][0]["hotelBasicInfo"]["reviewAverage"])
# Out:
# 天然温泉　田沢湖レイクリゾート
# https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=4624&f_flg=PLAN
# 5060
# 4.1

# %% [markdown]
# ### 4.2.データの確認と扱い方

# %% [markdown]
# 取得しただけではデータを活用できないので、取得したデータを扱っていきます。
#
# 全体像としては
# - 取得したjsonデータを確認
# - jsonでは確認しずらく、扱いずらいので、pandasというライブラリを使って扱いやすくする

# %% [markdown]
# #### 取得したデータの中身を詳しく確認してみましょう。

# %% [markdown]
# ※取得したデータの全体像

# %% [markdown]
# <img style="background-color:#fff;" src="img/img034.png">
# <img style="background-color:#fff;" src="img/img035.png">

# %% [markdown]
# 参照：https://jsoncrack.com/editor

# %% [markdown]
# 取得したデータの内容は result['hotels'][ここ行の場所]['hotel'][0]['hotelBasicInfo'] に格納されており、
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']とすることで、１つ目に格納されているホテルの詳細を取得する事ができます

# %%
# データの中身を紐解いていく

result['hotels'][0]['hotel'][0]['hotelBasicInfo']
# Out:
# {'hotelNo': 4624,
#  'hotelName': '天然温泉\u3000田沢湖レイクリゾート',
#  'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=4624',
#  'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=4624&f_flg=PLAN',
#  'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=4624',
#  'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=4624',
#  'hotelKanaName': 'てんねんおんせん\u3000たざわこれいくりぞーと',
#  'hotelSpecial': '水深日本一の田沢湖の近く、スキー場・グラウンド・ゴルフ場認定コースあり',
#  'hotelMinCharge': 5060,
#  'latitude': 143059.23,
#  'longitude': 506645.02,
#  'postalCode': '014-1201',
#  'address1': '秋田県',
#  'address2': '仙北市田沢湖生保内字下高野82-117',
#  'telephoneNo': '0187-46-2016',
#  'faxNo': '0187-46-2241',
#  'access': 'JR秋田新幹線田沢湖駅からバスで２０分、盛岡Ｉ．Ｃから５０分。田沢湖駅から送迎バスにて約15分（要事前予約）',
#  'parkingInformation': '有り\u3000５００台\u3000無料',
#  'nearestStation': '田沢湖',
#  'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/4624/4624.jpg',
#  'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/4624.jpg',
#  'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/4624/4624_room.jpg',
#  'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/4624.jpg',
#  'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/4624/4624map.gif',
#  'reviewCount': 1448,
#  'reviewAverage': 4.1,
#  'userReview': '露天風呂が利用でかなかったのが残念でした。部屋はきれいで気持ち良ったです。\u30002023-10-14 17:34:45投稿'}

# %% [markdown]
# どんなホテルの詳細情報項目があるか確認してみましょう！
# result['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()で確認することができます。

# %%
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']になんの項目が含まれているかをkeys()で確認できます。
result['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()
# Out:
# dict_keys(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl', 'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial', 'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1', 'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation', 'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl', 'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage', 'userReview'])

# %% [markdown]
# hotelNameという項目があるので、ホテルの名前などを取得してみましょう

# %%
# ホテル名の取得
result['hotels'][0]['hotel'][0]['hotelBasicInfo']["hotelName"]
# Out:
# '天然温泉\u3000田沢湖レイクリゾート'

# %%
#URLの取得
result['hotels'][0]['hotel'][0]['hotelBasicInfo']["hotelInformationUrl"]
# Out:
# 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=4624'

# %%
# 最低料金
result['hotels'][0]['hotel'][0]['hotelBasicInfo']["hotelMinCharge"]
# Out:
# 5060

# %%
# 平均レビュー
result['hotels'][0]['hotel'][0]['hotelBasicInfo']["reviewAverage"]
# Out:
# 4.1

# %% [markdown]
# #### データを扱いやすくするために可視化する

# %% [markdown]
# ##### pandasを使ったデータの可視化

# %% [markdown]
# APIで得られたデータをpandasを用いてエクセルのような見やすいデータに変換してみましょう！

# %% [markdown]
# ライブラリのpandasをインポートしましょう！
# as pdとつけて、短くpdとコーディングできるようにします。

# %%
#pandasのインポート
import pandas as pd

# %% [markdown]
# データをpandasのDataFrameに格納してみましょう！
# また、DataFrameとはどのような変換をしてくれるか確認してみましょう。

# %%
# １つめのホテルのデータをhotel_infoに代入します。
hotel_info = result['hotels'][0]['hotel'][0]['hotelBasicInfo']

# pd.DataFrame(ここに変換したいデータ,index=[ここにpandasに認識してほしい行数indexの番号])を代入します。
pd.DataFrame(hotel_info, index=[0])
# Out:
#    hotelNo        hotelName  \
# 0     4624  天然温泉　田沢湖レイクリゾート
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl         hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  てんねんおんせん　たざわこれいくりぞーと
#
#                           hotelSpecial  hotelMinCharge   latitude  ...  \
# 0  水深日本一の田沢湖の近く、スキー場・グラウンド・ゴルフ場認定コースあり            5060  143059.23  ...
#
#    parkingInformation nearestStation  \
# 0          有り　５００台　無料            田沢湖
#
#                                        hotelImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/4...
#
#                                    hotelThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/90/4624.jpg
#
#                                         roomImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/4...
#
#                                     roomThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                     hotelMapImageUrl reviewCount  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/4...        1448
#
#   reviewAverage                                         userReview
# 0           4.1  露天風呂が利用でかなかったのが残念でした。部屋はきれいで気持ち良ったです。　2023-10-...
#
# [1 rows x 27 columns]

# %% [markdown]
# indexの数字を変数iにして、他のホテル情報も確認してみましょう！
# iの数字を変えると取得できるホテルを変更できる事も確認してみましょう

# %%
#index番号の指定。ここの数字を変えると格納されるデータが変わります。
i = 0

# その番号に対応するホテル情報を取得し、hotel_infoに代入
hotel_info = result['hotels'][i]['hotel'][0]['hotelBasicInfo']

# pd.DataFrame(ここに変換したいデータ,index=[ここにpandasに認識してほしい行数indexの番号])を代入します。
pd.DataFrame(hotel_info,index=[i])
# Out:
#    hotelNo        hotelName  \
# 0     4624  天然温泉　田沢湖レイクリゾート
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl         hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  てんねんおんせん　たざわこれいくりぞーと
#
#                           hotelSpecial  hotelMinCharge   latitude  ...  \
# 0  水深日本一の田沢湖の近く、スキー場・グラウンド・ゴルフ場認定コースあり            5060  143059.23  ...
#
#    parkingInformation nearestStation  \
# 0          有り　５００台　無料            田沢湖
#
#                                        hotelImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/4...
#
#                                    hotelThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/90/4624.jpg
#
#                                         roomImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/4...
#
#                                     roomThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                     hotelMapImageUrl reviewCount  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/4...        1448
#
#   reviewAverage                                         userReview
# 0           4.1  露天風呂が利用でかなかったのが残念でした。部屋はきれいで気持ち良ったです。　2023-10-...
#
# [1 rows x 27 columns]

# %% [markdown]
# 個別のデータを格納できたので、データ全体を格納してみましょう。
#
# そのためにAPIで取得したホテルのデータ数を確認してみましょう！
# len(確認したい配列)でデータ数を確認できます！

# %%
# len(ここに配列に含まれる要素)で配列に含まれる要素の数を取得できます。
len(result["hotels"])
# Out:
# 30

# %% [markdown]
# 30あるホテルのデータをfor文を使ってまとめてみましょう！

# %%
#空のpandasデータフレームを用意して、生成した1つ１つのデータフレームをこのdfに結合して１つにします。
df = pd.DataFrame()

# iにrange(0,len(result['hotels']))である0～29の数字が１つずつ代入されて実行されます。
# 今回は30のデータとわかっているのでfor i in range(0,30)でも問題ないですが、30とは限らないのでデータ園生数であるlen(result['hotels'])を使います。
for i in range(0,len(result["hotels"])):
    hotel_info = result['hotels'][i]['hotel'][0]['hotelBasicInfo'] 
    temp_df = pd.DataFrame(hotel_info,index=[i]) 
    df = pd.concat([df,temp_df]) 
    
#格納する配列をhotel_infoに代入する
#hotel_infoに代入されたホテルのデータをデータフレームに変換します。

#dfに結合して１つにまとめます。

# %% [markdown]
# まとめたデータをdisplay(df) で確認してみましょう！

# %%
# dfの表示
display(df)
# Out:
#     hotelNo                   hotelName  \
# 0      4624             天然温泉　田沢湖レイクリゾート
# 1     15408           日本の山岳温泉リゾート　新玉川温泉
# 2     14338            効能溢れる癒しの湯治宿　玉川温泉
# 3     70699               ホテルルートイン　大曲駅前
# 4     11222                  亀の井ホテル　田沢湖
# 5    162983                 リバーサイドホテル大曲
# 6    161208                     町家ホテル角館
# 7     72803                   休暇村　乳頭温泉郷
# 8    145044                    大曲シティホテル
# 9     10867                   グリーンホテル大曲
# 10   107856                   田町武家屋敷ホテル
# 11    20646                Ｔａｂｉｓｔ　ホテル富士
# 12   139459                     花心亭しらはま
# 13    70772       田沢湖水沢温泉郷セルリアンリゾートＡＯＮＩ
# 14     1720     ホテルフォルクローロ角館＜JR東日本ホテルズ＞
# 15     5576                あきた芸術村　温泉ゆぽぽ
# 16     5387         心に和みが灯る宿　水沢温泉郷　青荷山荘
# 17    13886                  大曲エンパイヤホテル
# 18   181765                   川口温泉　奥羽山荘
# 19    59623                  乳頭温泉郷　大釜温泉
# 20   129680                   ホテルグランド天空
# 21   107777              南玉川温泉　湯宿　はなやの森
# 22    16520             田沢湖高原温泉　田沢高原ホテル
# 23   162793               湖畔浪漫の宿　かたくりの花
# 24   141336                   夏瀬温泉　都わすれ
# 25   128566                    角館温泉　花葉館
# 26     2763  田沢湖畔の小さなリゾート　ペンションサウンズグッド！
# 27   147002             かくのだて温泉　町宿　ねこの鈴
# 28    44352                      民宿　惣之助
# 29   178536                       和のゐ角館
#
#                                   hotelInformationUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                           planListUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                         dpPlanListUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                             reviewUrl  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                         hotelKanaName  \
# 0                てんねんおんせん　たざわこれいくりぞーと
# 1           にほんの山岳おんせんりぞーと　しんたまがわおんせん
# 2                            たまがわおんせん
# 3                     るーといん　おおまがりえきまえ
# 4                        かめのいほてる たざわこ
# 5                      りばーさいどほてるおおまがり
# 6                         まちやほてるかくのだて
# 7                 きゅうかむら　にゅうとうおんせんぎょう
# 8                         おおまがりしてぃほてる
# 9                       ぐりーんほてる　おおまがり
# 10                        たまちぶけやしきほてる
# 11                         たびすと　ほてるふじ
# 12                          かしんていしらはま
# 13        たざわこみずさわおんせんきょうせるりあんりぞーとあおに
# 14                      ふぉるくろーろ　かくのだて
# 15                たざわこげいじゅつむら　おんせんゆぽぽ
# 16  こころになごみがともるやど　みずさわおんせんきょう　あおにさんそう
# 17                     おおまがり　えんぱいやほてる
# 18                   かわぐちおんせん　おううさんそう
# 19                           おおがまおんせん
# 20                           ぐらんどてんくう
# 21             みなみたまがわおんせん　ゆやど　はなやのもり
# 22            たざわここうげんおんせん　たざわこうげんほてる
# 23                  こはんろまんのやど　かたくりのはな
# 24                     なつせおんせん　みやこわすれ
# 25                     かくのだておんせんかようかん
# 26       たざわこはんのちいさなりぞーとぺんしょん　さうんずぐっと
# 27               かくのだておんせん　まちやど　ねこのすず
# 28                              そうのすけ
# 29                           わのいかくのだて
#
#                                          hotelSpecial  hotelMinCharge  \
# 0                 水深日本一の田沢湖の近く、スキー場・グラウンド・ゴルフ場認定コースあり            5060
# 1                        強酸性日本一と言われる玉川温泉の源泉をそのまま掛け流し！           12100
# 2                            日帰り入浴は午前9:00〜午後3:30までです。            5170
# 3    ＷＯＷＯＷ全室で無料視聴可■VODルームシアター無料視聴可能（一般映画のみ）（コンフォート特典）            5125
# 4               2023年10月1日より「亀の井ホテル 田沢湖」へリブランドいたしました。            4200
# 5     【２０１７年８月 リニューアルオープン！！】 日本一の花火の街、大曲のビジネス・観光の新拠点♪            4500
# 6   小京都角館にマッチした和風でモダンなホテル。武家屋敷通りまで徒歩２分・観光やビジネスにも最適...            7480
# 7   美しいブナ林に囲まれた静かな宿です。温泉浴や森林浴が楽しめ、ここでは時間がゆっくりと流れています。           15500
# 8                                                立地良好            2750
# 9         ビジネス、観光に便利なＪＲ大曲駅西口徒歩3分・全室インターネット接続可能（無線LAN)            4250
# 10      小京都角館に佇む黒板塀に囲まれた蔵造の宿。民芸調の客室と、創作料理がお楽しみいただけます。           10230
# 11          【全室和室LAN完備】【大曲駅徒歩3分】【コンビニ徒歩5分】【秋田米おいしい朝食】            3300
# 12  ＜全室専用ダイニングルーム付き客室＞田沢湖畔に望み、秋田の風土とこだわりぬいた郷土懐石を愉しむ宿。           21500
# 13   ★2023年リブランド！美肌成分たっぷりの源泉かけ流しの露天風呂付き大浴場と地元食材の料理が好評            8000
# 14       秋田新幹線「角館駅」となり♪武家屋敷通りまで徒歩圏内☆田沢湖駅までひと駅 全室Wi-Fi            5450
# 15                 わらび劇場にてミュージカルや工芸館で陶芸体験などをお楽しみ頂けます。            6050
# 16      秋田竿燈まつりをコンセプトに2021年全室リニューアル！貸切天然温泉と地元食材の料理が好評           10000
# 17  【17時〜19時半レストラン利用で1ドリンクサービス】大曲駅から徒歩8分／無料駐車場／朝食個別配膳            5775
# 18            原風景が広がる豊かな自然と抜群の開放感！ご家族やペットとゆっくり穏やかな時間を            6050
# 19  温泉ファンをうならせる乳頭温泉は24時間入浴OK。露天・内湯ともに男女別。家庭的な山里料理に舌鼓。           11000
# 20    ブナ林に囲まれた田沢湖高原に佇む「ホテルグランド天空」は、全室から水深日本一の田沢湖が望めます            8500
# 21  秘境玉川宝仙湖に佇む「湯宿　はなやの森」当館自慢の露天風呂付客室で、ごゆっくりお寛ぎくださいませ。           22000
# 22   家族で営む、山の温泉宿。　施設は古くなってまいりましたが、ハードよりハートを大切にしております。            6050
# 23  田沢湖畔まで徒歩1分。湖を眺めるお部屋と無料展望貸切露天風呂。田沢湖の美しい景色を楽しむ癒しの空間           15840
# 24   江戸時代から薬湯として親しまれてきた秘湯、和と洋が融合したモダンジャパニーズの寛ぎの空間が待つ。           37350
# 25   角館美人を育む肌に優しい温泉を源泉かけ流しで！露天風呂、ミストサウナ、泡風呂など数種類楽しめる◎            7150
# 26    ジャズが流れる大人の隠れ家！第1土曜は生演奏♪ロフト造りのB&B☆北東北観光のベースキャンプ！            7370
# 27         【源泉かけ流し天然温泉】角館駅から一番近い宿。隣接の「土間人」で秋田料理も味わえる★            6600
# 28  閑静な環境、季節折々の山菜、自家栽培の有機野菜、自慢の“あきたこまち”と化石の宿です。長期滞...            7000
# 29       「角館古民家ホテル」は、武家屋敷で有名な小京都「角館」の歴史ある蔵を改装したホテルです。           14500
#
#      latitude  ...                                parkingInformation  \
# 0   143059.23  ...                                        有り　５００台　無料
# 1   143854.53  ...       有り（無料）。　冬期間は田沢湖駅近くに無料駐車場有り。ご利用の際は、お問い合せ下さい。
# 2   143858.55  ...                    宿から5分ほど離れた場所にあります。当日係がご案内致します。
# 3   142062.57  ...          有り　７０台　無料　予約不要 先着順  ※満車の際は近隣駐車場をご案内致します｡
# 4   143205.33  ...                                    有り　100台　無料　先着順
# 5   142048.69  ...        18台の無料駐車場有り（先着順となります）※満車の際は近隣の駐車場をご案内致します。
# 6   142533.62  ...                                        有り　25台　無料
# 7   143273.15  ...                                   有り　１００台　無料　予約不要
# 8   142065.11  ...  徒歩５分のところにあり　台数限りあり　先着順　２トン車まで 　春、夏花火前後のは利用できません。
# 9   142068.59  ...                                     有り　８０台　先着順　無料
# 10  142518.36  ...                                     有り　９台　無料　予約不要
# 11  142061.15  ...                                     有り　２０台　無料　先着順
# 12  143032.59  ...                                    有り　３０台　無料　予約不要
# 13  143142.65  ...                                       無料／40台／予約不要
# 14  142518.61  ...                    有り　１２台　無料　(満車の場合は近隣の無料駐車場にご案内）
# 15  142589.21  ...                                    有り　２００台　無料　先着順
# 16  143143.41  ...                                 【あり】無料／１6台まで／予約不要
# 17  142069.42  ...                                     有り　７０台　無料　先着順
# 18  142208.01  ...                                   有り　150台　無料　予約不要
# 19  143285.89  ...                                    有り　３０台　無料　予約不要
# 20  143206.45  ...                                    有り　２５台　無料　予約不要
# 21  143465.09  ...                                                 有
# 22  143194.32  ...                                     有り　16台　無料　先着順
# 23  143034.41  ...                                        有り　無料　予約不要
# 24  142658.10  ...                                     有り　３０台　無料　要予約
# 25  142625.54  ...                                   有り　100台　無料　予約不要
# 26  143073.63  ...                                           有10台　無料
# 27  142523.09  ...                                      有り　5台　無料　要予約
# 28  143029.12  ...                                    有り　１０台　無料　予約不要
# 29  142524.63  ...                                        有り　無料　予約不要
#
#    nearestStation                                      hotelImageUrl  \
# 0             田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/4...
# 1             田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 2             田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 3          大曲（秋田）  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 4             田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 5          大曲（秋田）  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 6              角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 7             田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 8          大曲（秋田）  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 9          大曲（秋田）  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 10             角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 11         大曲（秋田）  https://img.travel.rakuten.co.jp/share/HOTEL/2...
# 12            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 13            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 14             角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 15             角館  https://img.travel.rakuten.co.jp/share/HOTEL/5...
# 16            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/5...
# 17         大曲（秋田）  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 18             角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 19            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/5...
# 20            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 21            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 22            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 23            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 24             角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 25             角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 26            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/2...
# 27             角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 28            田沢湖  https://img.travel.rakuten.co.jp/share/HOTEL/4...
# 29             角館  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                     hotelThumbnailUrl  \
# 0   https://img.travel.rakuten.co.jp/HIMG/90/4624.jpg
# 1   https://img.travel.rakuten.co.jp/HIMG/90/15408...
# 2   https://img.travel.rakuten.co.jp/HIMG/90/14338...
# 3   https://img.travel.rakuten.co.jp/HIMG/90/70699...
# 4   https://img.travel.rakuten.co.jp/HIMG/90/11222...
# 5   https://img.travel.rakuten.co.jp/HIMG/90/16298...
# 6   https://img.travel.rakuten.co.jp/HIMG/90/16120...
# 7   https://img.travel.rakuten.co.jp/HIMG/90/72803...
# 8   https://img.travel.rakuten.co.jp/HIMG/90/14504...
# 9   https://img.travel.rakuten.co.jp/HIMG/90/10867...
# 10  https://img.travel.rakuten.co.jp/HIMG/90/10785...
# 11  https://img.travel.rakuten.co.jp/HIMG/90/20646...
# 12  https://img.travel.rakuten.co.jp/HIMG/90/13945...
# 13  https://img.travel.rakuten.co.jp/HIMG/90/70772...
# 14  https://img.travel.rakuten.co.jp/HIMG/90/1720.jpg
# 15  https://img.travel.rakuten.co.jp/HIMG/90/5576.jpg
# 16  https://img.travel.rakuten.co.jp/HIMG/90/5387.jpg
# 17  https://img.travel.rakuten.co.jp/HIMG/90/13886...
# 18  https://img.travel.rakuten.co.jp/HIMG/90/18176...
# 19  https://img.travel.rakuten.co.jp/HIMG/90/59623...
# 20  https://img.travel.rakuten.co.jp/HIMG/90/12968...
# 21  https://img.travel.rakuten.co.jp/HIMG/90/10777...
# 22  https://img.travel.rakuten.co.jp/HIMG/90/16520...
# 23  https://img.travel.rakuten.co.jp/HIMG/90/16279...
# 24  https://img.travel.rakuten.co.jp/HIMG/90/14133...
# 25  https://img.travel.rakuten.co.jp/HIMG/90/12856...
# 26  https://img.travel.rakuten.co.jp/HIMG/90/2763.jpg
# 27  https://img.travel.rakuten.co.jp/HIMG/90/14700...
# 28  https://img.travel.rakuten.co.jp/HIMG/90/44352...
# 29  https://img.travel.rakuten.co.jp/HIMG/90/17853...
#
#                                          roomImageUrl  \
# 0   https://img.travel.rakuten.co.jp/share/HOTEL/4...
# 1   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 2   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 3   https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 4   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 5   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 6   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 7   https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 8                                                None
# 9   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 10  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 11  https://img.travel.rakuten.co.jp/share/HOTEL/2...
# 12  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 13  https://img.travel.rakuten.co.jp/share/HOTEL/7...
# 14  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 15  https://img.travel.rakuten.co.jp/share/HOTEL/5...
# 16  https://img.travel.rakuten.co.jp/share/HOTEL/5...
# 17  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 18                                               None
# 19  https://img.travel.rakuten.co.jp/share/HOTEL/5...
# 20  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 21  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 22  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 23  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 24  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 25  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 26  https://img.travel.rakuten.co.jp/share/HOTEL/2...
# 27  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 28                                               None
# 29  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                      roomThumbnailUrl  \
# 0   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 1   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 2   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 3   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 4   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 5   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 6   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 7   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 8                                                None
# 9   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 10  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 11  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 12  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 13  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 14  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 15  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 16  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 17  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 18                                               None
# 19  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 20  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 21  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 22  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 23  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 24  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 25  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 26  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 27  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 28                                               None
# 29  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                      hotelMapImageUrl reviewCount  \
# 0   https://img.travel.rakuten.co.jp/share/HOTEL/4...        1448
# 1   https://img.travel.rakuten.co.jp/share/HOTEL/1...        1006
# 2   https://img.travel.rakuten.co.jp/share/HOTEL/1...         584
# 3   https://img.travel.rakuten.co.jp/share/HOTEL/7...        1204
# 4   https://img.travel.rakuten.co.jp/share/HOTEL/1...         870
# 5   https://img.travel.rakuten.co.jp/share/HOTEL/1...         286
# 6   https://img.travel.rakuten.co.jp/share/HOTEL/1...         253
# 7   https://img.travel.rakuten.co.jp/share/HOTEL/7...         394
# 8   https://img.travel.rakuten.co.jp/share/HOTEL/1...         427
# 9   https://img.travel.rakuten.co.jp/share/HOTEL/1...        1198
# 10  https://img.travel.rakuten.co.jp/share/HOTEL/1...         141
# 11  https://img.travel.rakuten.co.jp/share/HOTEL/2...         436
# 12  https://img.travel.rakuten.co.jp/share/HOTEL/1...          84
# 13  https://img.travel.rakuten.co.jp/share/HOTEL/7...         236
# 14  https://img.travel.rakuten.co.jp/share/HOTEL/1...         668
# 15  https://img.travel.rakuten.co.jp/share/HOTEL/5...         392
# 16  https://img.travel.rakuten.co.jp/share/HOTEL/5...         213
# 17  https://img.travel.rakuten.co.jp/share/HOTEL/1...         393
# 18  https://img.travel.rakuten.co.jp/share/HOTEL/1...          60
# 19  https://img.travel.rakuten.co.jp/share/HOTEL/5...         355
# 20  https://img.travel.rakuten.co.jp/share/HOTEL/1...         237
# 21  https://img.travel.rakuten.co.jp/share/HOTEL/1...         109
# 22  https://img.travel.rakuten.co.jp/share/HOTEL/1...         253
# 23  https://img.travel.rakuten.co.jp/share/HOTEL/1...          16
# 24  https://img.travel.rakuten.co.jp/share/HOTEL/1...          61
# 25  https://img.travel.rakuten.co.jp/share/HOTEL/1...          79
# 26  https://img.travel.rakuten.co.jp/share/HOTEL/2...         194
# 27  https://img.travel.rakuten.co.jp/share/HOTEL/1...          73
# 28  https://img.travel.rakuten.co.jp/share/HOTEL/4...          45
# 29  https://img.travel.rakuten.co.jp/share/HOTEL/1...          18
#
#    reviewAverage                                         userReview
# 0           4.10  露天風呂が利用でかなかったのが残念でした。部屋はきれいで気持ち良ったです。　2023-10-...
# 1           4.39  昨年同時期に初めて伺い妻と又行きたいよね！って行ってたときに土日の現場がリスケになり急遽検索...
# 2           4.43             温泉は最高で雰囲も気最高でした。　2023-10-14 11:53:12投稿
# 3           4.09  楽天から予約時、2名予約のため禁煙、喫煙の区別ができず、喫煙を予約し、コメントに1名禁煙希望...
# 4           3.86  食事、部屋と大変満足して子供もまた泊まりに行きたいと言ってました。1つだけ残念だったのはチェ...
# 5           3.78  １泊２食付きで、このお値段なら満足です。ご飯のおかわりが自由なのも、ハラペコにはグッド。近く...
# 6           4.33  ９月２２日に宿泊しました。近くに温泉もあり良かったです。　2023-09-30 10:26:...
# 7           4.55  3月24日に宿泊しました。お風呂とお食事が素晴らしかったです。また、利用したい宿です。　20...
# 8           2.38  簡易シャワーとは書いてあったがトイレにシャワーが付いているなかなかすごい部屋も古いなるべく安...
# 9           3.93  急用ができたので一泊追加できて助かりました。ただ前日までの部屋から端の部屋に移ったらWi-F...
# 10          4.64  （週末の大雨対応お疲れさまですm(_ _)m）早めの到着になりましたが、部屋の準備を早めてい...
# 11          3.95  朝食は美味しいです。現在、夕食がないのが残念でした。部屋に関しては布団式で値段の割りには良い...
# 12          4.44  おもてなしと食事が最高でした。丁寧な接客に知りたい情報を詳しく教えていただき、旅行をより楽し...
# 13          4.11  温泉に湯の華ではなく汚れが浮いていてがっかりでした。特に露天は脚を入れる気にならないほどでし...
# 14          4.17  近隣のホテルも空きがなく探していたらちょうどこちらが空いていて立地がよく助かりました。快適に...
# 15          4.59  ゆったりとした広いお部屋と、気持ちの良い大浴場で、とてもくつろげました。スタッフの方も皆さん...
# 16          4.09  ゆっくり休むことができました料理も美味しかったですが鍋料理だけ、味が濃すぎましたそれが残念で...
# 17          3.52                 アメニティが有料は初めて　2023-10-03 12:34:38投稿
# 18          4.00  接客は丁寧で気持ちよかったです。食事は美味しく、オーナーが日本酒をサービスしてまわってました...
# 19          3.43                                               None
# 20          4.17                                               None
# 21          3.00                                               None
# 22          4.63  秋田駒ヶ岳登山の前泊で利用。田沢湖駅からのバス停が目の前で、なおかつ「アルパこまくさ」まで徒...
# 23          3.90                                               None
# 24          4.00                                               None
# 25          4.19  朝食バイキング、空になっても補充されずメインはほぼ空、残り物を頂きました　2023-10-0...
# 26          4.67                                               None
# 27          4.00                                               None
# 28          4.55                                               None
# 29          4.25                                               None
#
# [30 rows x 27 columns]

# %% [markdown]
# df.columnsで項目の確認ができます！
# これはresult['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()で取得した値と一致します

# %%
#カラムの表示
df.columns
# Out:
# Index(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl',
#        'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial',
#        'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1',
#        'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation',
#        'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl',
#        'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage',
#        'userReview'],
#       dtype='object')

# %% [markdown]
# ##### pandasを使ったデータ整理

# %% [markdown]
# まとめたデータから名前と値段と評価だけを取り出してみましょう！
# １つのカラムを取得する時は欲しいカラム名である"カラム名"を代入したdf["カラム名"]で取得できましたが、
# 複数選択する場合は、の代わりに配列である["カラム名1","カラム名2","カラム名3"]を代入してdf[["カラム名1","カラム名2","カラム名3"]]とする必要があります。

# %%
#[ 'hotelName', 'hotelMinCharge', 'reviewAverage']を表示

df[[ 'hotelName', 'hotelMinCharge', 'reviewAverage']]
# Out:
#                      hotelName  hotelMinCharge  reviewAverage
# 0              天然温泉　田沢湖レイクリゾート            5060           4.10
# 1            日本の山岳温泉リゾート　新玉川温泉           12100           4.39
# 2             効能溢れる癒しの湯治宿　玉川温泉            5170           4.43
# 3                ホテルルートイン　大曲駅前            5125           4.09
# 4                   亀の井ホテル　田沢湖            4200           3.86
# 5                  リバーサイドホテル大曲            4500           3.78
# 6                      町家ホテル角館            7480           4.33
# 7                    休暇村　乳頭温泉郷           15500           4.55
# 8                     大曲シティホテル            2750           2.38
# 9                    グリーンホテル大曲            4250           3.93
# 10                   田町武家屋敷ホテル           10230           4.64
# 11                Ｔａｂｉｓｔ　ホテル富士            3300           3.95
# 12                     花心亭しらはま           21500           4.44
# 13       田沢湖水沢温泉郷セルリアンリゾートＡＯＮＩ            8000           4.11
# 14     ホテルフォルクローロ角館＜JR東日本ホテルズ＞            5450           4.17
# 15                あきた芸術村　温泉ゆぽぽ            6050           4.59
# 16         心に和みが灯る宿　水沢温泉郷　青荷山荘           10000           4.09
# 17                  大曲エンパイヤホテル            5775           3.52
# 18                   川口温泉　奥羽山荘            6050           4.00
# 19                  乳頭温泉郷　大釜温泉           11000           3.43
# 20                   ホテルグランド天空            8500           4.17
# 21              南玉川温泉　湯宿　はなやの森           22000           3.00
# 22             田沢湖高原温泉　田沢高原ホテル            6050           4.63
# 23               湖畔浪漫の宿　かたくりの花           15840           3.90
# 24                   夏瀬温泉　都わすれ           37350           4.00
# 25                    角館温泉　花葉館            7150           4.19
# 26  田沢湖畔の小さなリゾート　ペンションサウンズグッド！            7370           4.67
# 27             かくのだて温泉　町宿　ねこの鈴            6600           4.00
# 28                      民宿　惣之助            7000           4.55
# 29                       和のゐ角館           14500           4.25

# %% [markdown]
# 欲しいデータに絞って出力してみましょう！
# pandasの機能であるto_csvを使うとcsvファイルとして保存ができます

# %%
# dfの'hotelName', 'hotelInformationUrl', 'hotelMinCharge', 'telephoneNo', 'reviewAverage'を指定して、
# ここにデータフレーム.to_csv(ここにファイル名,データフレームで認識されているindex数字も出力するかどうか)で保存できます。
# このデータではindexの数字は必要ないので、index = Falseにします。

df[[ 'hotelName', 'hotelInformationUrl', 
       'hotelMinCharge', 'telephoneNo', 'reviewAverage',
       ]].to_csv('hotel.csv',index = False),
# Out:
# (None,)

# %% [markdown]
# 今度は保存したcsvをdf2として読み込んでみましょう！

# %%
# pd.read_csv(ここにファイル名)でロードして、df2に代入します。
df2 = pd.read_csv("hotel.csv")

# %% [markdown]
# まとめたデータから評価が4.5以上のホテルを検索してみましょう！

# %%
# df[ ここにそれぞれの行に対して出力するかどうかの条件文　]でデータを抽出できます。
# 今回は評価が4.5以上なので、df['reviewAverage'] > 4.5を条件とします。

df[ df['reviewAverage'] > 4.5]

df2 = df[ df['reviewAverage'] < 3]
df2 = df2[['hotelName','reviewAverage','userReview']]
display(df2)

df2[['hotelName','reviewAverage','userReview']].to_csv("hotel2.csv", index=False)
# Out:
#   hotelName  reviewAverage                                         userReview
# 8  大曲シティホテル           2.38  簡易シャワーとは書いてあったがトイレにシャワーが付いているなかなかすごい部屋も古いなるべく安...

# %% [markdown]
# ### 課題

# %% [markdown]
# 検索して絞ったデータをdf2に格納して、ホテル名と評価とレビューだけ出力してみましょう！

# %%
# レビュー4.5以上を絞り込む
# ホテル名と評価とレビューだけ出力

# %% [markdown]
# - 同じ要領で楽天トラベル以外の楽天市場のデータを取得してください。
# - たどったフローを箇条書きまたは図式化してTAに提出してチェックうけてください
# - 発展
#     - 他のサービスのAPIで自分で構造化データまで取得してください。
#     - それを人に説明してください
