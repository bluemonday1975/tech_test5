# %% [markdown]
# # Webアプリに入る前に知っておくべきデータに関する前提知識

# %% [markdown]
# ### 目標：APIを理解して使いこなし、そのデータを扱えるようになる事
#
# 目次
# https://docs.google.com/document/d/1crmJ0DjAl77ab9aK8K9DshfQu25fS3EWXCC0m4AajZo/edit

# %% [markdown]
# ## 3全体像：楽天のAPIから情報を取得する

# %% [markdown]
# ### 3.1.おさらい：APIとは？

# %% [markdown]
# APIは、Application Programming Interfaceの略であり、プログラムやアプリケーション開発に必要な機能やデータを提供するインターフェースを指します。
#
# 例として、スマートフォンにはカメラアプリや音楽アプリ、地図アプリなどが存在します。これらのアプリケーションは、スマートフォンのOS（Operating System）が提供するAPIを用いて、カメラやGPS機能といったハードウェアやソフトウェアにアクセスしています。
#
# APIはアプリケーションが他のアプリケーションやシステムと連携する手段であり、開発者が他のアプリケーションやサービスと容易に連携できるように設計されています。APIにはWeb API、データベースAPI、ソーシャルメディアAPIなど、多様な種類があります。
#
# オンラインランキングやアカウントログイン機能の開発の際、GoogleやFacebookなどのサービスが提供するAPIを利用してアカウント情報を取得することができます。
#
# APIは現代のソフトウェア開発において極めて重要な役割を担っており、様々なアプリケーションやサービスで利用されています。
#
# 今回取り上げる楽天APIを利用すれば、ホテルの価格比較サイトなどで活用することが可能です。

# %% [markdown]
# ### 3.2.実際にやる事

# %% [markdown]
# SimpleHotelSearchにアクセスして、沖縄の那覇市のホテル情報を取得します。

# %% [markdown]
# <img src="img/img032.jpg">

# %% [markdown]
# 参照：https://www.ebisumart.com/blog/ec-api/

# %%
import requests #ライブラリrequestsを使うためにimportすることで機能を使う事が出来ます。
# アクセス先と認証と要求するデータの内容を指定します。
REQUEST_URL = 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426' #アクセス先を指定する必要があるので、アクセス先をREQUEST_URLという変数に代入しておきます。
APP_ID = '1011509919335500197' #ここのの数字動画では伏せる　# アクセスを許可されたユーザーという事を証明するために、APP_IDに認証IDを代入しておきます。
# アクセス先と認証を用意できたので、なんのデータが欲しいかをparamsに代入しておきます。
# paramsでの指定方法はAPIの作成者によって変わりますので、事前に確認しておく必要があります。
params = {
    'format':'json',
    'largeClassCode': 'japan',
    'middleClassCode': 'okinawa',
    'smallClassCode': 'nahashi',
    'applicationId': APP_ID    
}

# アクセス先と認証と要求するデータの内容を指定出来たので、requestsのgetメソッドを使ってアクセスします。
# その結果をresに代入します。
res = requests.get(REQUEST_URL, params)

# 欲しいデータはresのjsonに格納されているので、res.json()をresultに代入しておきましょう。
# これでAPIで取得したデータはresultに代入されます。
result = res.json()

# %%
# 実際にresultに格納されたデータを見てみましょう。
result
# Out:
# {'pagingInfo': {'recordCount': 413,
#   'pageCount': 14,
#   'page': 1,
#   'first': 1,
#   'last': 30},
#  'hotels': [{'hotel': [{'hotelBasicInfo': {'hotelNo': 148000,
#       'hotelName': 'ハイアットリージェンシー那覇沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=148000',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=148000&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=148000',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=148000',
#       'hotelKanaName': 'はいあっとりーじぇんしーなはおきなわ',
#       'hotelSpecial': 'グローバルブランドならではの洗練されたおもてなしと空間で上質なホテルステイをお楽しみください。',
#       'hotelMinCharge': 7106,
#       'latitude': 94357.69,
#       'longitude': 459690.88,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-6-20',
#       'telephoneNo': '098-866-8888',
#       'faxNo': '098-866-8111',
#       'access': '那覇空港から車で約２０分、ゆいレール「牧志駅」から徒歩７分 、国際通りまで徒歩3分',
#       'parkingInformation': '立体駐車場・地下駐車場完備\u3000１１３台\u30001泊1台あたり1,500円（税込）\u3000（予約不要／出し入れ自由）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/148000.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000_kan.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/148000.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000map.gif',
#       'reviewCount': 604,
#       'reviewAverage': 4.65,
#       'userReview': '家族で1泊宿泊しました。お部屋はシックで心地よく、朝食のカレーパンが大変美味しかったです。スタッフのおもてなしも素晴らしく、さすがハイアットさんだと思いました。立地も良く、また宿泊したいです。\u30002023-04-03 16:18:56投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.64,
#       'locationAverage': 4.52,
#       'roomAverage': 4.62,
#       'equipmentAverage': 4.62,
#       'bathAverage': 4.24,
#       'mealAverage': 4.55}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 134763,
#       'hotelName': 'ダイワロイネットホテル那覇おもろまち',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=134763',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=134763&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=134763',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=134763',
#       'hotelKanaName': 'だいわろいねっとほてるなはおもろまち',
#       'hotelSpecial': '海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎',
#       'hotelMinCharge': 3650,
#       'latitude': 94389.24,
#       'longitude': 459709.57,
#       'postalCode': '900-0006',
#       'address1': '沖縄県',
#       'address2': '那覇市おもろまち1-1-12',
#       'telephoneNo': '098-862-4555',
#       'faxNo': '098-862-4556',
#       'access': 'ゆいレール\u3000おもろまち駅より徒歩５分\u3000国際通りより車で5分',
#       'parkingInformation': '1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用下さい。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/134763.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763_tw.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/134763.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763map.gif',
#       'reviewCount': 944,
#       'reviewAverage': 4.4,
#       'userReview': '朝食の内容が、期待以上でした。眺めも良く満足です。ゆいレールの駅からのアクセスが、問題です。道路を挟んで向かい側ですが、道路を横断する場所が、離れているため遠回りしなければならない事です。\u30002023-04-08 21:34:04投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.16,
#       'locationAverage': 4.14,
#       'roomAverage': 4.47,
#       'equipmentAverage': 4.04,
#       'bathAverage': 3.82,
#       'mealAverage': 4.15}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 177761,
#       'hotelName': '東急ステイ沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=177761',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=177761&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=177761',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=177761',
#       'hotelKanaName': 'とうきゅうすてい\u3000おきなわ\u3000なは',
#       'hotelSpecial': '食事評価4.2★沖縄料理が満載♪空港からゆいレールで4駅の好立地、全室洗濯乾燥機&ミニキッチン完備！',
#       'hotelMinCharge': 4025,
#       'latitude': 94334.89,
#       'longitude': 459646.33,
#       'postalCode': '900-0025',
#       'address1': '沖縄県',
#       'address2': '那覇市壷川3-2-1',
#       'telephoneNo': '098-833-1090',
#       'faxNo': '098-833-1091',
#       'access': '沖縄都市モノレール線\u3000壷川駅より徒歩にて約３分',
#       'parkingInformation': '屋内契約駐車場30台 1500円 入出庫可 屋内提携駐車場123台 1200円 1回出庫毎に料金発生',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/177761.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761map.gif',
#       'reviewCount': 528,
#       'reviewAverage': 4.59,
#       'userReview': 'フロント、部屋がとてもセンスの良いインテリアで、水場（お風呂、洗面台、ミニキッチン）も使い勝手が良く、洗濯機も大変助かりました。自宅から忘れ物をして困っていたのですが、同ビル内にあるドンキホーテで…\u30002023-04-05 14:34:02投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=177761" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.32,
#       'locationAverage': 4.6,
#       'roomAverage': 4.67,
#       'equipmentAverage': 4.31,
#       'bathAverage': 4.16,
#       'mealAverage': 4.37}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181785,
#       'hotelName': 'ヒューイットリゾート那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181785',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181785&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181785',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785',
#       'hotelKanaName': 'ひゅーいっとりぞーとなは',
#       'hotelSpecial': '2021年7月15日OPEN！朝食ブッフェは宿泊の皆様に無料でご提供いたします！',
#       'hotelMinCharge': 5320,
#       'latitude': 94371.18,
#       'longitude': 459711.73,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2丁目5番16号',
#       'telephoneNo': '098-943-8325',
#       'faxNo': '098-943-8326',
#       'access': 'モノレール安里駅から徒歩3分\u3000バス国内線旅客ターミナル発120番安里下車徒歩3分\u3000タクシー那覇空港より約20分',
#       'parkingInformation': '有り\u300084台',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181785.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785map.gif',
#       'reviewCount': 205,
#       'reviewAverage': 4.26,
#       'userReview': '安里駅から３分なので雨でもすぐです。コンビニまでは少しあります。大浴場がありません。部屋は狭く1人なら丁度いい広さです。バストイレが別。バスに洗濯物を広げる物干しがありませんでした。消毒済みと部屋入口…\u30002023-04-08 20:38:09投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.04,
#       'locationAverage': 4.44,
#       'roomAverage': 4.24,
#       'equipmentAverage': 4.1,
#       'bathAverage': 3.93,
#       'mealAverage': 4.3}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 104526,
#       'hotelName': 'ダイワロイネットホテル沖縄県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=104526',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=104526&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=104526',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=104526',
#       'hotelKanaName': 'だいわろいねっとほてるおきなわけんちょうまえ',
#       'hotelSpecial': '那覇空港より１５分。県庁等官庁街へ徒歩２分、人気の国際通りへは徒歩３分でビジネス・観光に好立地。',
#       'hotelMinCharge': 5330,
#       'latitude': 94353.12,
#       'longitude': 459642.44,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-2',
#       'telephoneNo': '098-860-1855',
#       'faxNo': '098-860-1856',
#       'access': '◆モノレール県庁前駅または旭橋駅 徒歩3分\u3000◆那覇空港 モノレール13分、車で約10分\u3000◆沖縄県庁、国際通り 徒歩3分',
#       'parkingInformation': '有り\u3000１台\u3000１０５０円（税込み／泊）\u3000先着順（予約不可）*満車の際は、近隣の有料駐車場へご案内。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/104526.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526_ro.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/104526.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526map.gif',
#       'reviewCount': 1111,
#       'reviewAverage': 4.26,
#       'userReview': '立地もよく、また利用したいホテルでした\u30002023-03-28 02:46:38投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.83,
#       'locationAverage': 4.28,
#       'roomAverage': 4.3,
#       'equipmentAverage': 3.94,
#       'bathAverage': 3.81,
#       'mealAverage': 3.41}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 182884,
#       'hotelName': 'ホテルリソルトリニティ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=182884',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182884&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=182884',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884',
#       'hotelKanaName': 'ほてるりぞるとりにてぃなは',
#       'hotelSpecial': '2022年4月1日開業。国際通りまで徒歩圏の絶好の立地。大浴場を備え、上質なくつろぎをご提供。',
#       'hotelMinCharge': 3700,
#       'latitude': 94341.93,
#       'longitude': 459641.13,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町7',
#       'telephoneNo': '098-863-9269',
#       'faxNo': '098-863-9279',
#       'access': 'ゆいレール「旭橋駅」出入口2より徒歩3分',
#       'parkingInformation': '有り 50台 1泊1,500円 ※台風・災害時など駐車場をご利用いただけない場合がございます。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182884.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884map.gif',
#       'reviewCount': 170,
#       'reviewAverage': 4.48,
#       'userReview': 'お値段がお得な割に部屋は綺麗だしお風呂も清潔、さらに朝食がとても美味しく満足です。国際通りには歩いて15分ほどかかりますがバスターミナルやモノレールの駅に近いので立地もいいと思います。朝食は沖…\u30002023-04-08 20:17:21投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.16,
#       'locationAverage': 4.4,
#       'roomAverage': 4.47,
#       'equipmentAverage': 4.26,
#       'bathAverage': 4.34,
#       'mealAverage': 4.38}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 160939,
#       'hotelName': 'ＪＲ九州ホテル\u3000ブラッサム那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=160939',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=160939&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=160939',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=160939',
#       'hotelKanaName': 'じぇいあーるきゅうしゅうほてる\u3000ぶらっさむなは',
#       'hotelSpecial': '国際通りむつみ橋交差点徒歩1分。ゆいレール美栄橋駅徒歩５分。',
#       'hotelMinCharge': 5900,
#       'latitude': 94367.2,
#       'longitude': 459682.25,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志2丁目16番１号',
#       'telephoneNo': '098-861-8700',
#       'faxNo': '098-862-8739',
#       'access': '那覇空港よりタクシーで約15分、ゆいレール\u3000美栄橋駅より徒歩にて約５分',
#       'parkingInformation': '有り\u3000１１２台\u3000１５００円（税込み／泊）\u3000予約不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/160939.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/160939.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939map.gif',
#       'reviewCount': 410,
#       'reviewAverage': 4.43,
#       'userReview': '朝食は９時３０分までに入室して１０時までと説明を受けていたが９時３０分がラストオーダーでした。９時２０分頃入室したが、ほとんど何もない皿ばかりで、リクエストして出してもらった。９時３０分ラストオーダー…\u30002023-04-06 15:46:46投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=160939" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.13,
#       'locationAverage': 4.59,
#       'roomAverage': 4.51,
#       'equipmentAverage': 4.07,
#       'bathAverage': 4.38,
#       'mealAverage': 4.26}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181495,
#       'hotelName': '沖縄逸の彩（ひので）\u3000温泉リゾートホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181495',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181495&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181495',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181495',
#       'hotelKanaName': 'おきなわひので\u3000おんせんりぞーとほてる',
#       'hotelSpecial': '【全国旅行支援キャンペーン対象施設】無料飲み放題がSNSで話題のホテル。モノレール駅まで徒歩1分。',
#       'hotelMinCharge': 4800,
#       'latitude': 94364.49,
#       'longitude': 459702.02,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-18-33',
#       'telephoneNo': '098-863-8877',
#       'faxNo': '098-863-5566',
#       'access': '那覇空港からゆいレールで16分。牧志駅徒歩1分。泊港(とまりん)からタクシーで6分、徒歩15分。国際通りから徒歩2分',
#       'parkingInformation': '先着10台まで駐車可能。 ＜１泊1,500円＞',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181495/181495.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181495.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181495/181495map.gif',
#       'reviewCount': 305,
#       'reviewAverage': 4.39,
#       'userReview': '家族3人で利用しました。モノレール駅からも近く、移動も楽でした。帰りは「国際通り」によって行きましたが、徒歩3分で到着しました。また利用したいと思います。\u30002023-04-07 17:42:06投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.25,
#       'locationAverage': 4.47,
#       'roomAverage': 4.12,
#       'equipmentAverage': 4.2,
#       'bathAverage': 3.54,
#       'mealAverage': 4.2}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 71990,
#       'hotelName': 'ホテル\u3000ロコア\u3000ナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=71990',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=71990&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=71990',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=71990',
#       'hotelKanaName': 'ろこあ\u3000なは',
#       'hotelSpecial': '目の前が国際通り！空港直通ゆいレール駅から徒歩2分！朝食バイキングは口コミでも高評価♪',
#       'hotelMinCharge': 5850,
#       'latitude': 94354.63,
#       'longitude': 459657.87,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-1-2',
#       'telephoneNo': '098-868-6578',
#       'faxNo': '098-868-6521',
#       'access': 'モノレール\u3000県庁前駅より徒歩２分',
#       'parkingInformation': '提携駐車場１泊1台１5００円。営業時間外の入出庫不可。先着順。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/71990.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990_ru.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/71990.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990map.gif',
#       'reviewCount': 1702,
#       'reviewAverage': 4.43,
#       'userReview': 'バイキングは口コミ通り美味しかったです。あぐー豚の塩麹焼きが美味しい。3回おかわりしました。レストランはそこまで広くないので8時頃行ったら3人で座れる席が空いてなかったので少し待ちました。あと食べ…\u30002023-04-06 21:15:43投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=71990" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.26,
#       'locationAverage': 4.74,
#       'roomAverage': 4.23,
#       'equipmentAverage': 4.12,
#       'bathAverage': 3.74,
#       'mealAverage': 4.45}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 136808,
#       'hotelName': 'リーガロイヤルグラン沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=136808',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=136808&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=136808',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=136808',
#       'hotelKanaName': 'りーがろいやるぐらんおきなわ',
#       'hotelSpecial': 'ゆいレール旭橋駅・那覇バスターミナル直結！「リーガ・マルシェ」スタッフ厳選の無料アメニティスタンド',
#       'hotelMinCharge': 6666,
#       'latitude': 94344.0,
#       'longitude': 459638.85,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町1-9',
#       'telephoneNo': '098-867-3331',
#       'faxNo': '098-867-3332',
#       'access': '【那覇空港から】車で約５分、ゆいレール「旭橋駅」下車\u3000駅から直結 【那覇バスターミナル】徒歩２分 【国際通り】徒歩１０分',
#       'parkingInformation': '有り\u3000料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します',
#       'nearestStation': '旭橋',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/136808.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/136808.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808map.gif',
#       'reviewCount': 590,
#       'reviewAverage': 4.61,
#       'userReview': '部屋からの眺望はいまいちでしたが、それ以外は全てすばらしかったです。今までは他のホテルを利用してましたが、これからはこちらをリピートしようと思いました。\u30002023-03-31 04:05:08投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.53,
#       'locationAverage': 4.67,
#       'roomAverage': 4.49,
#       'equipmentAverage': 4.55,
#       'bathAverage': 4.31,
#       'mealAverage': 4.47}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 167519,
#       'hotelName': 'ノボテル沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=167519',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=167519&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=167519',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519',
#       'hotelKanaName': 'のぼてる\u3000おきなわ\u3000なは',
#       'hotelSpecial': '国際通りから車で約５分、那覇にいてもリゾート気分を！クラブラウンジやインフィニティプールがあるホテル',
#       'hotelMinCharge': 3966,
#       'latitude': 94374.6,
#       'longitude': 459750.57,
#       'postalCode': '902-0062',
#       'address1': '沖縄県',
#       'address2': '那覇市松川40番地',
#       'telephoneNo': '098-887-1111',
#       'faxNo': '098-886-5591',
#       'access': '那覇空港から車で約25分、ゆいレール安里駅よりタクシーで約５分／徒歩約２０分',
#       'parkingInformation': '有り（1泊1台1,000円）\u3000※事前予約不可',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/167519.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/167519.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519map.gif',
#       'reviewCount': 351,
#       'reviewAverage': 4.35,
#       'userReview': '3月の飛び石連休の際に1泊しました。那覇空港からバスで行きましたが、1時間に1本くらいしかなくて駅から遠いのでやや不便なところにある感じです。ついたらホテルマンの人がでてきて荷物をすぐ運んでくれて…\u30002023-04-08 14:58:31投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.27,
#       'locationAverage': 3.63,
#       'roomAverage': 4.4,
#       'equipmentAverage': 4.1,
#       'bathAverage': 3.79,
#       'mealAverage': 3.96}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 38282,
#       'hotelName': 'ホテルパームロイヤルNAHA国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=38282',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=38282&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=38282',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=38282',
#       'hotelKanaName': 'ぱーむろいやる\u3000なは\u3000こくさいどおり',
#       'hotelSpecial': '＼国際通りから一歩入ると現れる楽園／ナノ水ロイヤルスパや朝食KUNCHIめしも人気',
#       'hotelMinCharge': 3715,
#       'latitude': 94365.08,
#       'longitude': 459689.04,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-9-10',
#       'telephoneNo': '098-865-5551',
#       'faxNo': '098-866-7711',
#       'access': '【ゆいレール】牧志駅下車徒歩2分（那覇空港から約25分）／【車】那覇空港より車で約15分\u3000',
#       'parkingInformation': '【有り：60台】1泊1100円（税込）満車の場合は近隣のコインパーキングをご利用下さい。※先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/38282.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/38282.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282map.gif',
#       'reviewCount': 2231,
#       'reviewAverage': 4.31,
#       'userReview': '国際通りからも大変便利なホテルです。プールサイドで朝食をいただきました。空港からゆいレールでの利便性も良くぜひまた利用させていただきたいホテルです。\u30002023-04-08 09:31:09投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.34,
#       'locationAverage': 4.79,
#       'roomAverage': 4.18,
#       'equipmentAverage': 4.14,
#       'bathAverage': 4.29,
#       'mealAverage': 4.35}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181957,
#       'hotelName': 'ＯＭＯ５沖縄那覇\u3000ｂｙ\u3000星野リゾート',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181957',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181957&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181957',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957',
#       'hotelKanaName': 'おも５\u3000おきなわなは\u3000ばい\u3000ほしのりぞーと',
#       'hotelSpecial': '国際通りから徒歩8分の好アクセス★寝るだけでは終わらせない、旅のテンションをあげるホテル',
#       'hotelMinCharge': 5500,
#       'latitude': 94368.45,
#       'longitude': 459654.1,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山１丁目3-16',
#       'telephoneNo': '05031348095',
#       'faxNo': '098-869-3787',
#       'access': '県庁前駅より徒歩6分、美栄橋駅より徒歩8分。那覇空港より車8分で国際通り至近',
#       'parkingInformation': '立体駐車場44台（1泊￥1500・車高1.9Mまで）先着順10:00PM〜6:00AMは入出庫不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181957.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957map.gif',
#       'reviewCount': 61,
#       'reviewAverage': 4.23,
#       'userReview': '施設も部屋も清潔感があり綺麗でスタイリッシュで居心地がよかったです。フロントのスタッフの方もカフェの方もとても感じがよくスムーズに対応してくださったので良かったです。また沖縄に行く時があったら…\u30002023-04-04 14:38:38投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.04,
#       'locationAverage': 4.22,
#       'roomAverage': 4.35,
#       'equipmentAverage': 3.76,
#       'bathAverage': 3.55,
#       'mealAverage': 4.33}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 183095,
#       'hotelName': 'ホテルグランコンソルト那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=183095',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=183095&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=183095',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183095',
#       'hotelKanaName': 'ほてるぐらんこんそるとなは',
#       'hotelSpecial': '2022年9月OPEN！ご宿泊者様専用ラウンジ・コネクティングルーム・駐車場を完備。国際通り徒歩3分',
#       'hotelMinCharge': 5000,
#       'latitude': 94350.11,
#       'longitude': 459662.68,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-18-25',
#       'telephoneNo': '098-860-5577',
#       'faxNo': '098-860-5599',
#       'access': '那覇空港から車で約15分、ゆいレール「県庁前駅」より徒歩約５分',
#       'parkingInformation': '有り：28台\u3000料金：1,650円/泊 (税込み）高さ制限がございます。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183095/183095.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/183095.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183095/183095map.gif',
#       'reviewCount': 42,
#       'reviewAverage': 4.55,
#       'userReview': '子供との旅行で一泊泊まりました。県庁駅も国際通りも近く、とても便利でした。お部屋はピカピカで、スタッフの方の対応もよく、快適に過ごせました。電気ポットがあれば。。とも思いましたが、…\u30002023-03-31 17:31:41投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183095" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.4,
#       'locationAverage': 4.58,
#       'roomAverage': 4.57,
#       'equipmentAverage': 4.2,
#       'bathAverage': 4.48,
#       'mealAverage': 4.08}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 16443,
#       'hotelName': 'ロワジールホテル那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=16443',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=16443&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=16443',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16443',
#       'hotelKanaName': 'ろわじーるほてるなは',
#       'hotelSpecial': '空港から車で約7分。天然温泉大浴場、室内外プールと館内施設が充実♪■楽天認定プレミアムホテル■',
#       'hotelMinCharge': 4377,
#       'latitude': 94355.14,
#       'longitude': 459603.97,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1台1,800円',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/16443.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443_heya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/16443.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443map.gif',
#       'reviewCount': 1310,
#       'reviewAverage': 4.03,
#       'userReview': '那覇で温泉を楽しめるなんて嬉しい限り。近くには地元スーパーや居酒屋もあり、バスターミナルにも近く、利便性が高かったです。\u30002023-04-06 18:04:04投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.89,
#       'locationAverage': 3.87,
#       'roomAverage': 3.98,
#       'equipmentAverage': 3.75,
#       'bathAverage': 4.06,
#       'mealAverage': 4}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 128440,
#       'hotelName': 'ダイワロイネットホテル那覇国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=128440',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=128440&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=128440',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440',
#       'hotelKanaName': 'だいわろいねっと\u3000なはこくさいどおり',
#       'hotelSpecial': '国際通りは目の前！ゆいレール「牧志」駅直結の好立地！！ビジネス・観光の拠点に最適♪',
#       'hotelMinCharge': 4500,
#       'latitude': 94369.8,
#       'longitude': 459703.77,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2-1-1',
#       'telephoneNo': '098-868-9055',
#       'faxNo': '098-868-9056',
#       'access': 'ゆいレール「牧志」駅直結！！那覇空港からモノレールで約20分♪',
#       'parkingInformation': '当館裏手に提携駐車場（商業施設併設の立体駐車場）へのご案内となります（先着順：1泊1,000円）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/128440.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440_sin.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/128440.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440map.gif',
#       'reviewCount': 1392,
#       'reviewAverage': 4.4,
#       'userReview': '主人の希望でゆいレールの乗車を考えてのホテル選びでした。駅近でとても便利でした。次回も利用したいと思いました。楽天トラベルを初めて利用して、私でも簡単に予約できて、最高できた。トイレとバスの間隔や大き…\u30002023-04-02 16:37:30投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.12,
#       'locationAverage': 4.74,
#       'roomAverage': 4.31,
#       'equipmentAverage': 3.94,
#       'bathAverage': 3.68,
#       'mealAverage': 4.41}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 172986,
#       'hotelName': 'ホテルコレクティブ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=172986',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=172986&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=172986',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=172986',
#       'hotelKanaName': 'これくてぃぶ',
#       'hotelSpecial': '★★ ご宿泊者専用屋外プール 2023年4月1日(土)〜2023年10月31日(火)\u3000オープン\u3000★★',
#       'hotelMinCharge': 8000,
#       'latitude': 94359.78,
#       'longitude': 459673.87,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾2-5-7',
#       'telephoneNo': '098-860-8366',
#       'faxNo': '098-860-8362',
#       'access': 'ゆいレール\u3000県庁前駅より徒歩約７分',
#       'parkingInformation': '有り(１,５００円／1日)',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/172986/172986.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/172986.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/172986/172986map.gif',
#       'reviewCount': 83,
#       'reviewAverage': 4.8,
#       'userReview': 'とてもきれいで、立地も良く今まで利用したホテルの中でも最高ランクに値するホテルです。また沖縄に行く機会があったら是非泊まりたいです。\u30002023-03-30 16:27:24投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.74,
#       'locationAverage': 4.92,
#       'roomAverage': 4.86,
#       'equipmentAverage': 4.62,
#       'bathAverage': 4.48,
#       'mealAverage': 4.58}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 149369,
#       'hotelName': 'ホテルグレイスリー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=149369',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=149369&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=149369',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=149369',
#       'hotelKanaName': 'ぐれいすりーなは',
#       'hotelSpecial': '★国際通り徒歩0分！★バス・トイレ別で、観光・出張も快適に♪焼きたてあぐー豚が人気の朝食ビュッフェ',
#       'hotelMinCharge': 5050,
#       'latitude': 94356.9,
#       'longitude': 459663.7,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-3-6',
#       'telephoneNo': '098-867-6111',
#       'faxNo': '098-867-4311',
#       'access': '●ゆいレール「県庁前」駅徒歩5分／●「国際通り」徒歩0分。荷物が多くても、車が無くても楽々♪',
#       'parkingInformation': '近隣（徒歩5分ほど）のコインパーキングをご案内します。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/149369.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/149369.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369map.gif',
#       'reviewCount': 553,
#       'reviewAverage': 4.49,
#       'userReview': '手荷物をチェックイン前に預かって頂きたいのと、チェックイン(旅行支援クーポンの発行)をして頂きに、12時頃伺いました。40-50代ぐらいの男性が対応して下さいましたが、チェックイン時間の前だからか、終…\u30002023-03-27 23:59:50投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=149369" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.25,
#       'locationAverage': 4.71,
#       'roomAverage': 4.41,
#       'equipmentAverage': 4.1,
#       'bathAverage': 4.44,
#       'mealAverage': 4.35}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 176757,
#       'hotelName': '沖縄ハーバービューホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=176757',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=176757&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=176757',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=176757',
#       'hotelKanaName': 'おきなわはーばーびゅーほてる',
#       'hotelSpecial': '楽天トラベルからのご予約限定☆楽天専用ラウンジOPEN☆お飲み物やアメニティをご用意しております',
#       'hotelMinCharge': 3375,
#       'latitude': 94336.98,
#       'longitude': 459657.29,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎2-46',
#       'telephoneNo': '098-853-2111',
#       'faxNo': '098-835-9696',
#       'access': '那覇空港より車で10分・ゆいレール壷川駅/旭橋駅より徒歩約10分/国際通りまで徒歩約10分',
#       'parkingInformation': '有り\u3000１９０台\u3000１８００円（税込み／泊）\u3000先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/176757.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/176757.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757map.gif',
#       'reviewCount': 432,
#       'reviewAverage': 4.2,
#       'userReview': '国際通りから徒歩10分、モノレール駅からも徒歩6分とという素晴らしい立地！ホテル自体は少し古いですがお部屋は広々でバスが最高です。大きくお湯はすぐ溜まり疲れが取れます。アメニティは人数分置いて…\u30002023-03-26 17:48:37投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=176757" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.05,
#       'locationAverage': 3.78,
#       'roomAverage': 4.22,
#       'equipmentAverage': 3.93,
#       'bathAverage': 3.73,
#       'mealAverage': 3.91}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 78094,
#       'hotelName': 'ロワジールスパタワー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=78094',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=78094&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=78094',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=78094',
#       'hotelKanaName': 'ろわじーるすぱたわーなは',
#       'hotelSpecial': '天然温泉を24時間楽しめる客室有！全室バルコニー付、24時間利用できるフィットネスジム完備',
#       'hotelMinCharge': 8351,
#       'latitude': 94353.28,
#       'longitude': 459606.91,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1,800円/台',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/78094.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/78094.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094map.gif',
#       'reviewCount': 472,
#       'reviewAverage': 4.29,
#       'userReview': '毎年、家族でお世話になっています。プールもあり大浴場、露天風呂、サウナ１日じゃ足りないくらいです。今回は12階のバーも利用させてもらいました。また来年もリラックスしに行きたいです。\u30002023-04-06 11:41:10投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.11,
#       'locationAverage': 3.95,
#       'roomAverage': 4.34,
#       'equipmentAverage': 4.26,
#       'bathAverage': 4.49,
#       'mealAverage': 3.79}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178447,
#       'hotelName': 'ＨＯＴＥＬ\u3000ＳＡＮＳＵＩ\u3000ＮＡＨＡ\u3000琉球温泉\u3000波之上の湯',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178447',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178447&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178447',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178447',
#       'hotelKanaName': 'ほてる\u3000さんすい\u3000なは\u3000りゅうきゅうおんせん\u3000なみのうえおんせん',
#       'hotelSpecial': '癒しの波上温泉とシースループール完備で那覇空港に一番近いスパ＆リゾート',
#       'hotelMinCharge': 4128,
#       'latitude': 94372.73,
#       'longitude': 459616.75,
#       'postalCode': '900-0037',
#       'address1': '沖縄県',
#       'address2': '那覇市辻2-25-1',
#       'telephoneNo': '098-860-7001',
#       'faxNo': '098-894-7303',
#       'access': '空港から車で約8分◆ホテルと那覇空港を結ぶシャトルバスも運行中◆崖の上の「縁結びパワースポット」波上宮まで【徒歩4分】',
#       'parkingInformation': '有り\u300042台\u30001,500円（税込み／泊）\u3000先着順\u3000※高さ制限有（175センチ）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178447.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447map.gif',
#       'reviewCount': 213,
#       'reviewAverage': 4.02,
#       'userReview': '温泉と波の上ビーチに行きたくて、宿泊しました。シーツを汚してしまったにも関わらず、凄く優しい対応をしてくださり、心が和みました。ありがとうございます。最上階のバーは、最高でした。一階の…\u30002023-04-02 12:11:25投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178447" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.91,
#       'locationAverage': 3.1,
#       'roomAverage': 3.88,
#       'equipmentAverage': 3.98,
#       'bathAverage': 4.13,
#       'mealAverage': 4.15}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 163087,
#       'hotelName': 'ホテルアクアチッタナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=163087',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=163087&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=163087',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=163087',
#       'hotelKanaName': 'ほてるあくあちったなは',
#       'hotelSpecial': '那覇唯一シースループール◆那覇の夜景を望めるナイトプールが人気◆地中海の朝市をコンセプトにした朝食',
#       'hotelMinCharge': 4446,
#       'latitude': 94385.53,
#       'longitude': 459666.2,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島3-2-20',
#       'telephoneNo': '098-866-5000',
#       'faxNo': '098-866-5600',
#       'access': '泊港離島ターミナルより徒歩30秒/美栄橋駅より徒歩7分/国際通りより徒歩約10分/那覇空港より車で約15分/国道58号沿',
#       'parkingInformation': '有 60台 1,200円（税込／泊）高さ制限1.55ｍ ※先着順\u3000その他のお車は近隣駐車場をご案内',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/163087.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/163087.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087map.gif',
#       'reviewCount': 326,
#       'reviewAverage': 4.37,
#       'userReview': '専用ラウンジが利用できることが魅力で選びました。ナッツ類と生ビールを含むアルコールも数種類選ぶことができ、部屋に持ち帰りも可能と言うこと無しでしたが、（気のせいかもしれませんが）生ビールが薄く感じられ…\u30002023-03-22 09:27:22投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=163087" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.19,
#       'locationAverage': 4.13,
#       'roomAverage': 4.13,
#       'equipmentAverage': 4.1,
#       'bathAverage': 3.83,
#       'mealAverage': 4.59}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 183747,
#       'hotelName': 'ホテル・アンドルームス那覇ポート',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=183747',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=183747&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=183747',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183747',
#       'hotelKanaName': 'ほてる・あんどるーむすなはぽーと',
#       'hotelSpecial': '那覇空港より車で7分。ルーフトッププールとサウナが楽しめるスタイリッシュ&カジュアルホテル。',
#       'hotelMinCharge': 2700,
#       'latitude': 94352.33,
#       'longitude': 459610.32,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西2丁目23-1',
#       'telephoneNo': '098-861-8111',
#       'faxNo': '098-861-8851',
#       'access': '那覇空港から車で7分、沖縄都市モノレール線「旭橋駅」から徒歩10分',
#       'parkingInformation': '有\u3000駐車場52台（内、機械式駐車場40台）※先着順、予約不可\u30001,500円(税込)/日',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183747/183747.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/183747.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183747/183747map.gif',
#       'reviewCount': 75,
#       'reviewAverage': 4.29,
#       'userReview': '部屋と部屋は、外でつながっています。また駅から遠く重い荷物をもって歩くには不便です。国際通りまでは、タクシーで行けますが、夜に行っても何もなく店も閉まっていて、家族で食事をするのに困りました。部屋も狭…\u30002023-03-15 05:09:55投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183747" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.03,
#       'locationAverage': 3.8,
#       'roomAverage': 4.4,
#       'equipmentAverage': 4.08,
#       'bathAverage': 3.78,
#       'mealAverage': 4.26}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 182682,
#       'hotelName': 'コンフォートイン那覇泊港',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=182682',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182682&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=182682',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182682',
#       'hotelKanaName': 'こんふぉーといんなはとまりこう',
#       'hotelSpecial': 'ポイント最大10倍得旅キャンペーン参加◆バストイレ別◆無料朝食◆小学生まで添寝無料◆美栄橋駅徒歩5分',
#       'hotelMinCharge': 3400,
#       'latitude': 94382.52,
#       'longitude': 459664.11,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島3-1-4',
#       'telephoneNo': '098-866-4711',
#       'faxNo': '098-866-4710',
#       'access': '沖縄都市モノレール（ゆいレール）「美栄橋」駅より徒歩約5分。国際通りまで徒歩約11分・久茂地まで徒歩約5分。',
#       'parkingInformation': '敷地内駐車場 34台 タワーパーキング先着順\u30001泊1,000円（PM15時〜AM11時）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182682/182682.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182682.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182682/182682map.gif',
#       'reviewCount': 170,
#       'reviewAverage': 4.41,
#       'userReview': '昨年より出張の常宿で利用してます。スタッフの方の対応が素晴らしく仕事も捗ります。設備についてはお風呂が気に入ってます。バストイレ別でお風呂は洗い場があるので浴槽でゆったり寛げます。私が一番…\u30002023-04-09 01:48:14投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182682" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.32,
#       'locationAverage': 4.35,
#       'roomAverage': 4.29,
#       'equipmentAverage': 3.98,
#       'bathAverage': 4.15,
#       'mealAverage': 3.87}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178292,
#       'hotelName': 'ホテル\u3000ストレータ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178292',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178292&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178292',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178292',
#       'hotelKanaName': 'すとれーたなは',
#       'hotelSpecial': '「美栄橋」から、新しい沖縄らしさを育み、発信していく場所となっていくことを目指しています。',
#       'hotelMinCharge': 4675,
#       'latitude': 94373.92,
#       'longitude': 459670.45,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志1丁目19番8号',
#       'telephoneNo': '098-860-7400',
#       'faxNo': '098-860-7410',
#       'access': 'ゆいレール「美栄橋駅」より徒歩30秒｜那覇空港より車で約16分｜国際通りまで徒歩約5分',
#       'parkingInformation': '立体駐車場48台：\\1,500/1泊\u3000到着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178292.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292map.gif',
#       'reviewCount': 187,
#       'reviewAverage': 4.4,
#       'userReview': '朝食が選べる所がとてもよかったです。立地も国際通りから近いですしまた機会があればよろしくお願いします。\u30002023-03-31 16:04:25投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.1,
#       'locationAverage': 4.79,
#       'roomAverage': 4.21,
#       'equipmentAverage': 4.03,
#       'bathAverage': 3.9,
#       'mealAverage': 4.23}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 171943,
#       'hotelName': '沖縄かりゆしリゾートエグゼス那覇＜県庁前＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=171943',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=171943&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=171943',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943',
#       'hotelKanaName': 'おきなわ\u3000かりゆし\u3000りぞーと\u3000えぐぜす\u3000なは',
#       'hotelSpecial': '那覇市内トップクラスの客室広さを誇るラグジュアリーホテル。朝食は全室ルームサービス（お部屋食）',
#       'hotelMinCharge': 8920,
#       'latitude': 94353.21,
#       'longitude': 459643.86,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-5',
#       'telephoneNo': '098-860-3300',
#       'faxNo': '098-860-3450',
#       'access': '那覇空港から車で約10分。モノレールご利用の場合は那覇空港駅→県庁前駅13分、下車、徒歩約4分。',
#       'parkingInformation': '有り\u3000４２台\u3000１５００円（税込み／泊）\u3000先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/171943.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943map.gif',
#       'reviewCount': 84,
#       'reviewAverage': 4.68,
#       'userReview': '誕生日と、長旅のラストを空港近くでゆっくり気分よく過ごしたく初めてこちらを利用しました。事前の荷物預けからお部屋の案内、広いお部屋、そして何よりお部屋でいただける朝食がすばらしく、まだあと1泊ある…\u30002023-04-03 12:58:02投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.66,
#       'locationAverage': 4.65,
#       'roomAverage': 4.79,
#       'equipmentAverage': 4.58,
#       'bathAverage': 4.59,
#       'mealAverage': 4.66}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 73870,
#       'hotelName': 'コンフォートホテル那覇県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=73870',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=73870&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=73870',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=73870',
#       'hotelKanaName': 'こんふぉーとほてるなはけんちょうまえ',
#       'hotelSpecial': 'ポイント最大10倍！得旅キャンペーン参加◆無料朝食◆小学6年生まで添い寝無料◆国際通り徒歩３分',
#       'hotelMinCharge': 3150,
#       'latitude': 94354.31,
#       'longitude': 459645.66,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地1-3-11',
#       'telephoneNo': '098-941-7311',
#       'faxNo': '098-941-7312',
#       'access': 'モノレール（ゆいレール）県庁前駅徒歩３分◆那覇空港モノレール１３分・車１０分◆沖縄県庁、国際通り徒歩３分',
#       'parkingInformation': '1泊820円（15：00〜翌12：00）敷地内駐車場5台',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/73870.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870_sig.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/73870.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870map.gif',
#       'reviewCount': 2699,
#       'reviewAverage': 4.18,
#       'userReview': '立地条件と費用対効果が良いです。\u30002023-04-08 16:21:28投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.1,
#       'locationAverage': 4.61,
#       'roomAverage': 3.97,
#       'equipmentAverage': 3.67,
#       'bathAverage': 3.29,
#       'mealAverage': 3.77}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 56974,
#       'hotelName': 'ホテルルートイン那覇泊港',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=56974',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=56974&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=56974',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=56974',
#       'hotelKanaName': 'ほてるるーといん\u3000なはとまりこう\u3000るーといんなはまえじま',
#       'hotelSpecial': '&#9830;14階展望大浴場完備&#9830;朝食無料サービス&#9830;WOWOW無料視聴可能',
#       'hotelMinCharge': 4050,
#       'latitude': 94384.67,
#       'longitude': 459667.7,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島2-12-5',
#       'telephoneNo': '098-866-0700',
#       'faxNo': '098-866-0710',
#       'access': '那覇空港より車で約１０分（４．５ｋｍ）/モノレール美栄橋駅より徒歩５分。',
#       'parkingInformation': '有り\u3000７２台\u3000５００円（税込み／泊）\u3000先着順\u3000（立体駐車場の為、高さ制限有１．５５mまで）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/56974/56974.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/56974.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/56974/56974_da.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/56974.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/56974/56974map.gif',
#       'reviewCount': 1214,
#       'reviewAverage': 4.18,
#       'userReview': '家族で2泊しました。室内は清潔で十分な広さでした。子連れだったこともあり、アメニティやグッズのプレゼントもありました。また、大浴場もとても気持ち良く、朝夕一回ずつ入らせて頂きました！…\u30002023-04-03 20:17:44投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=56974" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.09,
#       'locationAverage': 4.26,
#       'roomAverage': 3.83,
#       'equipmentAverage': 3.96,
#       'bathAverage': 4.17,
#       'mealAverage': 4.02}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 196,
#       'hotelName': 'ＣＯＭＭＵＮＩＴＹ＆ＳＰＡ\u3000那覇セントラルホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=196',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=196&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=196',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=196',
#       'hotelKanaName': 'なは\u3000せんとらるほてる',
#       'hotelSpecial': '国際通りまで徒歩約1分の好立地！併設の天然温泉では13種類のお風呂とサウナが滞在中何度でも利用可！',
#       'hotelMinCharge': 3135,
#       'latitude': 94371.5,
#       'longitude': 459685.55,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志2-16-36',
#       'telephoneNo': '098-862-6070',
#       'faxNo': '098-862-6109',
#       'access': '牧志バス停、モノレ－ル美栄橋駅牧志駅より徒歩約5分。美栄橋駅限定で無料送迎有り\u3000駅到着時連絡（10時～20時迄）',
#       'parkingInformation': '有り\u300080台\u3000普通車（1泊1台￥1,500税込）\u3000※予約不要（先着順）・24時間出し入れ可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/196/196.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/196.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/196/196_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/196.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/196/196map.gif',
#       'reviewCount': 533,
#       'reviewAverage': 4.04,
#       'userReview': '夫婦旅行で一泊二日のショートトリップで宿泊しました。国際通りから近く便利で、お部屋も綺麗。何より温泉施設が隣接しているので初日の歩き疲れもスッカリ癒されました。\u30002023-04-07 16:46:48投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.96,
#       'locationAverage': 4.4,
#       'roomAverage': 3.84,
#       'equipmentAverage': 3.62,
#       'bathAverage': 3.96,
#       'mealAverage': 4.03}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 18195,
#       'hotelName': 'サンプラザホテル＜沖縄県＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=18195',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=18195&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=18195',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=18195',
#       'hotelKanaName': 'さんぷらざほてる＜おきなわけん＞',
#       'hotelSpecial': 'ゆいレール牧志駅から徒歩5分。那覇のメインストリート国際通り近く、大浴場・コインランドリー有。',
#       'hotelMinCharge': 2000,
#       'latitude': 94378.86,
#       'longitude': 459694.79,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里138',
#       'telephoneNo': '098-866-0920',
#       'faxNo': '098-866-0929',
#       'access': '那覇空港から車で約15分・モノレール牧志駅から徒歩5分・崇元寺バス停前徒歩0分',
#       'parkingInformation': '有り\u3000先着順40台予約不可￥1000/泊※バス・大型車などの駐車は電話でお問合せ下さい。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/18195.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195_y.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/18195.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195map.gif',
#       'reviewCount': 2618,
#       'reviewAverage': 4.12,
#       'userReview': '１人で那覇に行くときはよく利用しています。モノレールの駅や国際通りから近く、近くに24時間営業のスーパーもあるのでとても便利です。お部屋はかなり経年を感じますが必要なものは揃っているので特に不便は感じ…\u30002023-04-07 22:33:24投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=18195" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.07,
#       'locationAverage': 4.2,
#       'roomAverage': 3.71,
#       'equipmentAverage': 3.53,
#       'bathAverage': 4.11,
#       'mealAverage': 3.89}}]}]}

# %% [markdown]
# ブラウザでもrequestsがアクセスしてる先をブラウザでも見てみましょう

# %%
# requestsがどんなURLでリクエストしたかをres.urlで確認出来ます。
res.url
# Out:
# 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?format=json&largeClassCode=japan&middleClassCode=okinawa&smallClassCode=nahashi&applicationId=1011509919335500197'

# %% [markdown]
# res.urlで出力したURLを整理してみると
#
# https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?
# format=json
# &largeClassCode=japan
# &middleClassCode=okinawa
# &smallClassCode=nahashi
# &applicationId=1011509919335500197
#
# となり、?の後ろ側にリクエストしたいパラメーターがついている事がわかります。

# %% [markdown]
# これは楽天トラベルに書いてある
#
# https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426?
# applicationId=[アプリID]
# &format=xml
# &largeClassCode=japan
# &middleClassCode=akita
# &smallClassCode=tazawa
#
# と要求してるパラメータの順番が違うだけで、同じ事を要求の仕方をしているのがわかると思います！
#
# requestでは?の後ろのパラメータを

# %%
params = {
    'format':'json',
    'largeClassCode': 'japan',
    'middleClassCode': 'okinawa',
    'smallClassCode': 'nahashi',
    'applicationId': APP_ID    
}

# %% [markdown]
# という形で格納し、requests.get(REQUEST_URL, params)で１つのリクエスト付きURLにしています。

# %% [markdown]
# よってURLの後ろにあるパラメータとrequestsのparamsが同じ変数を指定している事がわかりますね！
#
# URL属性以外にもrequests.Responseクラスには以下のような属性がある（一部）。

# %% [markdown]
# | 属性 | 説明 |
# | --- | --- |
# | text | レスポンスの内容（content属性）を文字列にデコードしたもの |
# | content | レスポントの内容（バイト列）。テキスト表現ではなくバイナリデータを扱うときにはこちらを使用する |
# | encoding | content属性をtext属性にデコードする際に使用したエンコーディング |
# | apparent_encoding | https://pypi.org/project/charset-normalizer/もしくはhttps://pypi.org/project/chardet/によって推測されたエンコーディング。encoding属性の値とapparent_encoding属性の値が異なることもある |
# | headers | レスポンスヘッダーを大文字小文字の区別をしない辞書の形式で格納したもの |
# | url | リクエストしたURL。リダイレクトが発生した場合には、リダイレクト先のURL |
# | history | get関数でリクエストしたURLがリダイレクトされた場合に、リダイレクトされた結果を示すrequests.Responseクラスのインスタンスを古いものから順に並べたリスト |
# |  |  |

# %% [markdown]
# requests.Responseクラスのインスタンスが持つ属性（一部）
# 参照：https://atmarkit.itmedia.co.jp/ait/articles/2209/27/news035.html

# %% [markdown]
# では、http経由でデータを取得する所から演習しましょう。

# %% [markdown]
# ### 3.3.http経由でデータを取得

# %% [markdown]
# #### http通信のリクエストをしてみよう

# %% [markdown]
# リクエストをするためのライブラリをインポートしておきましょう！

# %%
import requests #ライブラリrequestsを使うためにimportすることで機能を使う事が出来ます。

# %% [markdown]
# インポートすることによってrequestsの機能を使う事ができます。
# ではrequestsを使って、ブラウザのようにhtmlが取得できるかどうか確認してみましょう！
# requests.get("ここに接続したいサイトのURL")とすることでhtmlが取得できます。

# %% [markdown]
# <img src="img/img025.png">

# %% [markdown]
# 参照：https://www.itmanage.co.jp/column/about-http-https/

# %% [markdown]
# ブラウザと同じように取得できているかどうかは、ブラウザの検証機能にある、ページソース表示で確認できます！

# %%
#アクセスして取得したサイトデータをresに代入しておきます。
res = requests.get("https://tech0-jp.com/")

# %%
#resに代入しておいたサイトデータprintでかくにんします。
print(res.text)

#これを得られた結果とブラウザのページソース表示で得られるhtmlを比較して、ブラウザと同じ機能であることを確認しましょう！

# %% [markdown]
# #### 楽天からデータを取得してみましょう

# %% [markdown]
# 楽天側が用意した仕様に沿ったアクセス先とリクエストパラメータを設定していきましょう！
# アクセス先とAPIキーとパラメーターを設定します

# %%
# アクセス先と認証IDと要求するデータを指定します。
REQUEST_URL = 'https://app.rakuten.co.jp/services/api/Travel/SimpleHotelSearch/20170426'
APP_ID = '1011509919335500197' #ここのの数字動画では伏せる

# %%
params = {
    'format':'json',
    'largeClassCode': 'japan',
    'middleClassCode': 'okinawa',
    'smallClassCode': 'nahashi',
    'applicationId': APP_ID    
}

# %% [markdown]
# requests.get(アクセス先, リクエストパラメータ)を指定して、APIサーバーにデーターを要求しましょう！

# %%
# resにリクエストして得られた結果を代入します。
res = requests.get(REQUEST_URL, params)

# %% [markdown]
# リクエストが成功したか、ステータスの数字で確認しましょう！
# - 200なら正常に通信完了
# - 404ならアクセス先が間違えています。
# - その他の400番台はパラメータが間違えています！

# %%
#変数だけを指定する事でprint()を省略できます。
res
# Out:
# <Response [200]>

# %% [markdown]
# 通信の結果、返ってきたデータの中身を変数resultにjsonとして格納してから確認してみましょう！
# res.json()とすることで、レスポンスデータの中にあるjsonデータをしてすることができます。

# %%
# resultにresの中にあるjsonデータを代入します。
result = res.json()

# 代入したデータを見てみましょう。
result
# Out:
# {'pagingInfo': {'recordCount': 413,
#   'pageCount': 14,
#   'page': 1,
#   'first': 1,
#   'last': 30},
#  'hotels': [{'hotel': [{'hotelBasicInfo': {'hotelNo': 148000,
#       'hotelName': 'ハイアットリージェンシー那覇沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=148000',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=148000&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=148000',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=148000',
#       'hotelKanaName': 'はいあっとりーじぇんしーなはおきなわ',
#       'hotelSpecial': 'グローバルブランドならではの洗練されたおもてなしと空間で上質なホテルステイをお楽しみください。',
#       'hotelMinCharge': 6833,
#       'latitude': 94357.69,
#       'longitude': 459690.88,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-6-20',
#       'telephoneNo': '098-866-8888',
#       'faxNo': '098-866-8111',
#       'access': '那覇空港から車で約２０分、ゆいレール「牧志駅」から徒歩７分 、国際通りまで徒歩3分',
#       'parkingInformation': '立体駐車場・地下駐車場完備\u3000１１３台\u30001泊1台あたり1,500円（税込）\u3000（予約不要／出し入れ自由）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/148000.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000_kan.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/148000.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/148000/148000map.gif',
#       'reviewCount': 606,
#       'reviewAverage': 4.65,
#       'userReview': '朝食が大変美味しかったまた利用したいと思う\u30002023-04-22 22:10:02投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.64,
#       'locationAverage': 4.52,
#       'roomAverage': 4.63,
#       'equipmentAverage': 4.61,
#       'bathAverage': 4.21,
#       'mealAverage': 4.55}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 134763,
#       'hotelName': 'ダイワロイネットホテル那覇おもろまち',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=134763',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=134763&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=134763',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=134763',
#       'hotelKanaName': 'だいわろいねっとほてるなはおもろまち',
#       'hotelSpecial': '海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎',
#       'hotelMinCharge': 3550,
#       'latitude': 94389.24,
#       'longitude': 459709.57,
#       'postalCode': '900-0006',
#       'address1': '沖縄県',
#       'address2': '那覇市おもろまち1-1-12',
#       'telephoneNo': '098-862-4555',
#       'faxNo': '098-862-4556',
#       'access': 'ゆいレール\u3000おもろまち駅より徒歩５分\u3000国際通りより車で5分',
#       'parkingInformation': '1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用下さい。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/134763.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763_tw.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/134763.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763map.gif',
#       'reviewCount': 950,
#       'reviewAverage': 4.4,
#       'userReview': 'とても綺麗なホテルです。清掃もとても丁寧にされているようでした。部屋から海や飛行機、ゆいレールなど見れ眺望バツグンで部屋の広さも充分すぎるぐらい広く快適に過ごせました。気になった点はチェックイ…\u30002023-04-22 18:12:57投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=134763" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.14,
#       'locationAverage': 4.11,
#       'roomAverage': 4.47,
#       'equipmentAverage': 4.06,
#       'bathAverage': 3.82,
#       'mealAverage': 4.15}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 177761,
#       'hotelName': '東急ステイ沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=177761',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=177761&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=177761',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=177761',
#       'hotelKanaName': 'とうきゅうすてい\u3000おきなわ\u3000なは',
#       'hotelSpecial': '食事評価4.2★沖縄料理が満載♪空港からゆいレールで4駅の好立地、全室洗濯乾燥機&ミニキッチン完備！',
#       'hotelMinCharge': 3875,
#       'latitude': 94334.89,
#       'longitude': 459646.33,
#       'postalCode': '900-0025',
#       'address1': '沖縄県',
#       'address2': '那覇市壷川3-2-1',
#       'telephoneNo': '098-833-1090',
#       'faxNo': '098-833-1091',
#       'access': '沖縄都市モノレール線\u3000壷川駅より徒歩にて約３分',
#       'parkingInformation': '屋内契約駐車場30台 1500円 入出庫可 屋内提携駐車場123台 1200円 1回出庫毎に料金発生',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/177761.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/177761/177761map.gif',
#       'reviewCount': 530,
#       'reviewAverage': 4.6,
#       'userReview': '駅から近くて便利ですが、国際通りまでは少し遠かった。初日が23時くらいの到着でしたので、食事に困りました。フロントが5階で、部屋→フロント階→エレベーター乗り換えてエントランスが面倒でした…\u30002023-04-12 11:44:40投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=177761" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.32,
#       'locationAverage': 4.6,
#       'roomAverage': 4.66,
#       'equipmentAverage': 4.3,
#       'bathAverage': 4.15,
#       'mealAverage': 4.35}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181785,
#       'hotelName': 'ヒューイットリゾート那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181785',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181785&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181785',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785',
#       'hotelKanaName': 'ひゅーいっとりぞーとなは',
#       'hotelSpecial': '2021年7月15日OPEN！朝食ブッフェは宿泊の皆様に無料でご提供いたします！',
#       'hotelMinCharge': 4970,
#       'latitude': 94371.18,
#       'longitude': 459711.73,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2丁目5番16号',
#       'telephoneNo': '098-943-8325',
#       'faxNo': '098-943-8326',
#       'access': 'モノレール安里駅から徒歩3分\u3000バス国内線旅客ターミナル発120番安里下車徒歩3分\u3000タクシー那覇空港より約20分',
#       'parkingInformation': '有り\u300084台',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181785.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181785/181785map.gif',
#       'reviewCount': 212,
#       'reviewAverage': 4.26,
#       'userReview': '家族4人で普通に楽しくすごせました(^^)v部屋もキレイで満足です！朝食もビッフェで渋滞していましたが、スタッフが順番通り中で渋滞にならないように調整しながらやってました！雨でプール入れな…\u30002023-04-22 19:05:09投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181785" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.01,
#       'locationAverage': 4.45,
#       'roomAverage': 4.22,
#       'equipmentAverage': 4.06,
#       'bathAverage': 3.94,
#       'mealAverage': 4.26}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 104526,
#       'hotelName': 'ダイワロイネットホテル沖縄県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=104526',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=104526&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=104526',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=104526',
#       'hotelKanaName': 'だいわろいねっとほてるおきなわけんちょうまえ',
#       'hotelSpecial': '那覇空港より１５分。県庁等官庁街へ徒歩２分、人気の国際通りへは徒歩３分でビジネス・観光に好立地。',
#       'hotelMinCharge': 4275,
#       'latitude': 94353.12,
#       'longitude': 459642.44,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-2',
#       'telephoneNo': '098-860-1855',
#       'faxNo': '098-860-1856',
#       'access': '◆モノレール県庁前駅または旭橋駅 徒歩3分\u3000◆那覇空港 モノレール13分、車で約10分\u3000◆沖縄県庁、国際通り 徒歩3分',
#       'parkingInformation': '有り\u3000１台\u3000１０５０円（税込み／泊）\u3000先着順（予約不可）*満車の際は、近隣の有料駐車場へご案内。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/104526.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526_ro.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/104526.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/104526/104526map.gif',
#       'reviewCount': 1116,
#       'reviewAverage': 4.25,
#       'userReview': 'ダイワロイネットだけあり、サービスは満遍なく行き渡っています。また朝食は改善してほしいです\u30002023-04-22 16:22:51投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.82,
#       'locationAverage': 4.28,
#       'roomAverage': 4.29,
#       'equipmentAverage': 3.91,
#       'bathAverage': 3.8,
#       'mealAverage': 3.42}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 182884,
#       'hotelName': 'ホテルリソルトリニティ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=182884',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182884&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=182884',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884',
#       'hotelKanaName': 'ほてるりぞるとりにてぃなは',
#       'hotelSpecial': '2022年4月1日開業。国際通りまで徒歩圏の絶好の立地。大浴場を備え、上質なくつろぎをご提供。',
#       'hotelMinCharge': 3700,
#       'latitude': 94341.93,
#       'longitude': 459641.13,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町7',
#       'telephoneNo': '098-863-9269',
#       'faxNo': '098-863-9279',
#       'access': 'ゆいレール「旭橋駅」出入口2より徒歩3分',
#       'parkingInformation': '有り 50台 1泊1,500円 ※台風・災害時など駐車場をご利用いただけない場合がございます。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182884.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182884/182884map.gif',
#       'reviewCount': 174,
#       'reviewAverage': 4.47,
#       'userReview': '新しいホテルなので清潔感期待したのですが一番気になったのはアメニティのタオルが臭いがあり洗ってあるのかな？と思うほどで残念だった。その他はテーブルが小さく大きなテーブルの貸し出しを受けて何とか間に…\u30002023-04-22 20:44:19投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182884" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.17,
#       'locationAverage': 4.4,
#       'roomAverage': 4.48,
#       'equipmentAverage': 4.25,
#       'bathAverage': 4.35,
#       'mealAverage': 4.39}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 160939,
#       'hotelName': 'ＪＲ九州ホテル\u3000ブラッサム那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=160939',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=160939&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=160939',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=160939',
#       'hotelKanaName': 'じぇいあーるきゅうしゅうほてる\u3000ぶらっさむなは',
#       'hotelSpecial': '国際通りむつみ橋交差点徒歩1分。ゆいレール美栄橋駅徒歩５分。',
#       'hotelMinCharge': 5100,
#       'latitude': 94367.2,
#       'longitude': 459682.25,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志2丁目16番１号',
#       'telephoneNo': '098-861-8700',
#       'faxNo': '098-862-8739',
#       'access': '那覇空港よりタクシーで約15分、ゆいレール\u3000美栄橋駅より徒歩にて約５分',
#       'parkingInformation': '有り\u3000１１２台\u3000１５００円（税込み／泊）\u3000予約不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/160939.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/160939.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/160939/160939map.gif',
#       'reviewCount': 412,
#       'reviewAverage': 4.44,
#       'userReview': '初めての沖縄旅行なので国際通りの近くに拠点を置いて行動したいなと思いここに決めました。新しいホテルなのでロビーもお部屋も本当に綺麗です。ホテル全体的に和モダンなテイストで沖縄感は感じられないですが…\u30002023-04-18 00:02:29投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=160939" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.12,
#       'locationAverage': 4.6,
#       'roomAverage': 4.5,
#       'equipmentAverage': 4.06,
#       'bathAverage': 4.38,
#       'mealAverage': 4.17}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181495,
#       'hotelName': '沖縄逸の彩（ひので）\u3000温泉リゾートホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181495',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181495&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181495',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181495',
#       'hotelKanaName': 'おきなわひので\u3000おんせんりぞーとほてる',
#       'hotelSpecial': '【全国旅行支援キャンペーン対象施設】無料飲み放題がSNSで話題のホテル。モノレール駅まで徒歩1分。',
#       'hotelMinCharge': 4800,
#       'latitude': 94364.49,
#       'longitude': 459702.02,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-18-33',
#       'telephoneNo': '098-863-8877',
#       'faxNo': '098-863-5566',
#       'access': '那覇空港からゆいレールで16分。牧志駅徒歩1分。泊港(とまりん)からタクシーで6分、徒歩15分。国際通りから徒歩2分',
#       'parkingInformation': '先着10台まで駐車可能。 ＜１泊1,500円＞',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181495/181495.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181495.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181495/181495map.gif',
#       'reviewCount': 311,
#       'reviewAverage': 4.39,
#       'userReview': '無料ラウンジと無料飲み放題が最高でした!!!ラーメンも無料ではビックリするぐらい美味しいし、アルコールは自分で作るタイプだし種類が豊富過ぎました♪ただ、温泉ホテルということで温泉を楽しみにして…\u30002023-04-19 20:47:06投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181495" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.22,
#       'locationAverage': 4.47,
#       'roomAverage': 4.12,
#       'equipmentAverage': 4.18,
#       'bathAverage': 3.53,
#       'mealAverage': 4.17}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 71990,
#       'hotelName': 'ホテル\u3000ロコア\u3000ナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=71990',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=71990&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=71990',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=71990',
#       'hotelKanaName': 'ろこあ\u3000なは',
#       'hotelSpecial': '目の前が国際通り！空港直通ゆいレール駅から徒歩2分！朝食バイキングは口コミでも高評価♪',
#       'hotelMinCharge': 5800,
#       'latitude': 94354.63,
#       'longitude': 459657.87,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-1-2',
#       'telephoneNo': '098-868-6578',
#       'faxNo': '098-868-6521',
#       'access': 'モノレール\u3000県庁前駅より徒歩２分',
#       'parkingInformation': '提携駐車場１泊1台１5００円。営業時間外の入出庫不可。先着順。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/71990.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990_ru.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/71990.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/71990/71990map.gif',
#       'reviewCount': 1705,
#       'reviewAverage': 4.42,
#       'userReview': 'モノレール県庁前から近くなのですごく便利です。利用しませんでしたが、１階にはコンビニも併設されています。もちろん、ホテルの前は国際通り、沖縄料理、島唄、ステーキ、焼肉なんでもＯＫです。そし…\u30002023-04-22 22:10:11投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=71990" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.23,
#       'locationAverage': 4.74,
#       'roomAverage': 4.21,
#       'equipmentAverage': 4.1,
#       'bathAverage': 3.72,
#       'mealAverage': 4.45}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 136808,
#       'hotelName': 'リーガロイヤルグラン沖縄',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=136808',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=136808&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=136808',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=136808',
#       'hotelKanaName': 'りーがろいやるぐらんおきなわ',
#       'hotelSpecial': 'ゆいレール旭橋駅・那覇バスターミナル直結！「リーガ・マルシェ」スタッフ厳選の無料アメニティスタンド',
#       'hotelMinCharge': 6933,
#       'latitude': 94344.0,
#       'longitude': 459638.85,
#       'postalCode': '900-0029',
#       'address1': '沖縄県',
#       'address2': '那覇市旭町1-9',
#       'telephoneNo': '098-867-3331',
#       'faxNo': '098-867-3332',
#       'access': '【那覇空港から】車で約５分、ゆいレール「旭橋駅」下車\u3000駅から直結 【那覇バスターミナル】徒歩２分 【国際通り】徒歩１０分',
#       'parkingInformation': '有り\u3000料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します',
#       'nearestStation': '旭橋',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/136808.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/136808.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/136808/136808map.gif',
#       'reviewCount': 592,
#       'reviewAverage': 4.6,
#       'userReview': 'リピーターです。落ち着いて宿泊することができます。アメニティも自分には十分過ぎる満足感です。朝食のオムレツの焼き方、焼き加減が２日間で違っていたので、次回はその辺りもリクエストしてみようと思っています…\u30002023-04-14 17:36:43投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=136808" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.55,
#       'locationAverage': 4.69,
#       'roomAverage': 4.49,
#       'equipmentAverage': 4.58,
#       'bathAverage': 4.3,
#       'mealAverage': 4.46}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 167519,
#       'hotelName': 'ノボテル沖縄那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=167519',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=167519&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=167519',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519',
#       'hotelKanaName': 'のぼてる\u3000おきなわ\u3000なは',
#       'hotelSpecial': '国際通りから車で約５分、那覇にいてもリゾート気分を！クラブラウンジやインフィニティプールがあるホテル',
#       'hotelMinCharge': 3733,
#       'latitude': 94374.6,
#       'longitude': 459750.57,
#       'postalCode': '902-0062',
#       'address1': '沖縄県',
#       'address2': '那覇市松川40番地',
#       'telephoneNo': '098-887-1111',
#       'faxNo': '098-886-5591',
#       'access': '那覇空港から車で約25分、ゆいレール安里駅よりタクシーで約５分／徒歩約２０分',
#       'parkingInformation': '有り（1泊1台1,000円）\u3000※事前予約不可',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/167519.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/167519.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/167519/167519map.gif',
#       'reviewCount': 351,
#       'reviewAverage': 4.31,
#       'userReview': '3月の飛び石連休の際に1泊しました。那覇空港からバスで行きましたが、1時間に1本くらいしかなくて駅から遠いのでやや不便なところにある感じです。ついたらホテルマンの人がでてきて荷物をすぐ運んでくれて…\u30002023-04-08 14:58:31投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=167519" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.25,
#       'locationAverage': 3.59,
#       'roomAverage': 4.39,
#       'equipmentAverage': 4.08,
#       'bathAverage': 3.77,
#       'mealAverage': 3.93}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 38282,
#       'hotelName': 'ホテルパームロイヤルNAHA国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=38282',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=38282&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=38282',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=38282',
#       'hotelKanaName': 'ぱーむろいやる\u3000なは\u3000こくさいどおり',
#       'hotelSpecial': '＼国際通りから一歩入ると現れる楽園／ナノ水ロイヤルスパや朝食KUNCHIめしも人気',
#       'hotelMinCharge': 3715,
#       'latitude': 94365.08,
#       'longitude': 459689.04,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志3-9-10',
#       'telephoneNo': '098-865-5551',
#       'faxNo': '098-866-7711',
#       'access': '【ゆいレール】牧志駅下車徒歩4分（那覇空港から約25分）／【車】那覇空港より車で約15分\u3000',
#       'parkingInformation': '【有り：60台】1泊1100円（税込）満車の場合は近隣のコインパーキングをご利用下さい。※先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/38282.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/38282.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/38282/38282map.gif',
#       'reviewCount': 2233,
#       'reviewAverage': 4.28,
#       'userReview': '4/14に一泊しました。立地もよく、フロントの対応も親切で、部屋も相応に清潔十分。室内、浴場など、空気清浄機、窓開けなど、徹底した対応をしていました。安心して過ごせます。朝食も十分美味しそうでしたし、…\u30002023-04-18 02:54:42投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=38282" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.36,
#       'locationAverage': 4.79,
#       'roomAverage': 4.16,
#       'equipmentAverage': 4.16,
#       'bathAverage': 4.28,
#       'mealAverage': 4.31}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 181957,
#       'hotelName': 'ＯＭＯ５沖縄那覇\u3000ｂｙ\u3000星野リゾート',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=181957',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=181957&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=181957',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957',
#       'hotelKanaName': 'おも５\u3000おきなわなは\u3000ばい\u3000ほしのりぞーと',
#       'hotelSpecial': '国際通りから徒歩8分の好アクセス★寝るだけでは終わらせない、旅のテンションをあげるホテル',
#       'hotelMinCharge': 4900,
#       'latitude': 94368.45,
#       'longitude': 459654.1,
#       'postalCode': '900-0032',
#       'address1': '沖縄県',
#       'address2': '那覇市松山１丁目3-16',
#       'telephoneNo': '05031348095',
#       'faxNo': '098-869-3787',
#       'access': '県庁前駅より徒歩6分、美栄橋駅より徒歩8分。那覇空港より車8分で国際通り至近',
#       'parkingInformation': '立体駐車場44台（1泊￥1500・車高1.9Mまで）先着順10:00PM〜6:00AMは入出庫不可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/181957.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/181957/181957map.gif',
#       'reviewCount': 64,
#       'reviewAverage': 4.2,
#       'userReview': '3泊4日しました。部屋そのものはとてもきれいで、快適でした！ベッドとはまた別にソファーみたいなところがあって、食事をしたり、話をしたりするのに適していました。自分が泊まった部屋には冷蔵庫がなかったので…\u30002023-04-18 16:48:01投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=181957" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.02,
#       'locationAverage': 4.23,
#       'roomAverage': 4.36,
#       'equipmentAverage': 3.75,
#       'bathAverage': 3.52,
#       'mealAverage': 4.28}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 183095,
#       'hotelName': 'ホテルグランコンソルト那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=183095',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=183095&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=183095',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183095',
#       'hotelKanaName': 'ほてるぐらんこんそるとなは',
#       'hotelSpecial': '2022年9月OPEN！ご宿泊者様専用ラウンジ・コネクティングルーム・駐車場を完備。国際通り徒歩3分',
#       'hotelMinCharge': 5000,
#       'latitude': 94350.11,
#       'longitude': 459662.68,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-18-25',
#       'telephoneNo': '098-860-5577',
#       'faxNo': '098-860-5599',
#       'access': '那覇空港から車で約15分、ゆいレール「県庁前駅」より徒歩約５分',
#       'parkingInformation': '有り：28台\u3000料金：1,650円/泊 (税込み）高さ制限がございます。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183095/183095.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/183095.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183095/183095map.gif',
#       'reviewCount': 45,
#       'reviewAverage': 4.51,
#       'userReview': 'レンタカーで駐車場に入ったら、すぐに従業員の方か来てくれて、ホテル駐車場は有料であると説明あり、お隣のパーキングの方が安いなど丁寧な説明ありました。13階以上の宿泊プランだとアルコールとおつまみが…\u30002023-04-17 15:26:59投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183095" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.38,
#       'locationAverage': 4.51,
#       'roomAverage': 4.56,
#       'equipmentAverage': 4.16,
#       'bathAverage': 4.44,
#       'mealAverage': 4.07}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 16443,
#       'hotelName': 'ロワジールホテル那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=16443',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=16443&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=16443',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16443',
#       'hotelKanaName': 'ろわじーるほてるなは',
#       'hotelSpecial': '空港から車で約7分。天然温泉大浴場、室内外プールと館内施設が充実♪■楽天認定プレミアムホテル■',
#       'hotelMinCharge': 5525,
#       'latitude': 94355.14,
#       'longitude': 459603.97,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1台1,800円',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/16443.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443_heya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/16443.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/16443/16443map.gif',
#       'reviewCount': 1311,
#       'reviewAverage': 4.01,
#       'userReview': '良い点:ゆいレール旭橋駅から徒歩約10分、すぐ近くにスーパーがある、ディナービュッフェに蟹があった、1階にコンビニや大きいお土産屋さんがある、ビュッフェのジーマーミ豆腐ともずくが美味しい、ブルーシ…\u30002023-04-11 12:44:16投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=16443" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.87,
#       'locationAverage': 3.86,
#       'roomAverage': 3.95,
#       'equipmentAverage': 3.72,
#       'bathAverage': 4.01,
#       'mealAverage': 3.94}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 128440,
#       'hotelName': 'ダイワロイネットホテル那覇国際通り',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=128440',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=128440&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=128440',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440',
#       'hotelKanaName': 'だいわろいねっと\u3000なはこくさいどおり',
#       'hotelSpecial': '国際通りは目の前！ゆいレール「牧志」駅直結の好立地！！ビジネス・観光の拠点に最適♪',
#       'hotelMinCharge': 3000,
#       'latitude': 94369.8,
#       'longitude': 459703.77,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里2-1-1',
#       'telephoneNo': '098-868-9055',
#       'faxNo': '098-868-9056',
#       'access': 'ゆいレール「牧志」駅直結！！那覇空港からモノレールで約20分♪',
#       'parkingInformation': '当館裏手に提携駐車場（商業施設併設の立体駐車場）へのご案内となります（先着順：1泊1,000円）',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/128440.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440_sin.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/128440.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/128440/128440map.gif',
#       'reviewCount': 1397,
#       'reviewAverage': 4.39,
#       'userReview': '清潔で静かなお部屋でした。3人で宿泊したので一台はエキストラベッドだったのですが動く度にギーギーと音がするのが気になりました。正規のベッドは広く心地良いベッドだったのでエキストラベッドはそんな物な…\u30002023-04-18 21:22:26投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=128440" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.14,
#       'locationAverage': 4.75,
#       'roomAverage': 4.31,
#       'equipmentAverage': 3.94,
#       'bathAverage': 3.68,
#       'mealAverage': 4.44}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 172986,
#       'hotelName': 'ホテルコレクティブ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=172986',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=172986&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=172986',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=172986',
#       'hotelKanaName': 'これくてぃぶ',
#       'hotelSpecial': '★★ ご宿泊者専用屋外プール 2023年4月1日(土)〜2023年10月31日(火)\u3000オープン\u3000★★',
#       'hotelMinCharge': 8000,
#       'latitude': 94359.78,
#       'longitude': 459673.87,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾2-5-7',
#       'telephoneNo': '098-860-8366',
#       'faxNo': '098-860-8362',
#       'access': 'ゆいレール\u3000県庁前駅より徒歩約７分',
#       'parkingInformation': '有り(１,５００円／1日)',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/172986/172986.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/172986.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/172986/172986map.gif',
#       'reviewCount': 85,
#       'reviewAverage': 4.8,
#       'userReview': '立地もサービスも最高でした\u30002023-04-21 13:41:31投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.75,
#       'locationAverage': 4.92,
#       'roomAverage': 4.86,
#       'equipmentAverage': 4.63,
#       'bathAverage': 4.46,
#       'mealAverage': 4.63}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 149369,
#       'hotelName': 'ホテルグレイスリー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=149369',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=149369&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=149369',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=149369',
#       'hotelKanaName': 'ぐれいすりーなは',
#       'hotelSpecial': '★国際通り徒歩0分！★バス・トイレ別で、観光・出張も快適に♪焼きたてあぐー豚が人気の朝食ビュッフェ',
#       'hotelMinCharge': 5050,
#       'latitude': 94356.9,
#       'longitude': 459663.7,
#       'postalCode': '900-0014',
#       'address1': '沖縄県',
#       'address2': '那覇市松尾1-3-6',
#       'telephoneNo': '098-867-6111',
#       'faxNo': '098-867-4311',
#       'access': '●ゆいレール「県庁前」駅徒歩5分／●「国際通り」徒歩0分。荷物が多くても、車が無くても楽々♪',
#       'parkingInformation': '近隣（徒歩5分ほど）のコインパーキングをご案内します。',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/149369.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/149369.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/149369/149369map.gif',
#       'reviewCount': 558,
#       'reviewAverage': 4.48,
#       'userReview': '4月16日より２泊しました。国際通り沿いなので買い物、食事にとても便利でスタッフの皆さんも親切で、たいへん満足できました。次回も利用したいと思いました。\u30002023-04-19 16:59:03投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.21,
#       'locationAverage': 4.71,
#       'roomAverage': 4.39,
#       'equipmentAverage': 4.09,
#       'bathAverage': 4.46,
#       'mealAverage': 4.28}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 176757,
#       'hotelName': '沖縄ハーバービューホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=176757',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=176757&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=176757',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=176757',
#       'hotelKanaName': 'おきなわはーばーびゅーほてる',
#       'hotelSpecial': '楽天トラベルからのご予約限定☆楽天専用ラウンジOPEN☆お飲み物やアメニティをご用意しております',
#       'hotelMinCharge': 3375,
#       'latitude': 94336.98,
#       'longitude': 459657.29,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎2-46',
#       'telephoneNo': '098-853-2111',
#       'faxNo': '098-835-9696',
#       'access': '那覇空港より車で10分・ゆいレール壷川駅/旭橋駅より徒歩約10分/国際通りまで徒歩約10分',
#       'parkingInformation': '有り\u3000１９０台\u3000１８００円（税込み／泊）\u3000先着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/176757.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757_kan1.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/176757.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/176757/176757map.gif',
#       'reviewCount': 438,
#       'reviewAverage': 4.21,
#       'userReview': 'さすが沖縄の帝国ホテル。すべて最高レベルです。\u30002023-04-16 11:28:12投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.08,
#       'locationAverage': 3.79,
#       'roomAverage': 4.24,
#       'equipmentAverage': 3.96,
#       'bathAverage': 3.77,
#       'mealAverage': 3.96}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 78094,
#       'hotelName': 'ロワジールスパタワー那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=78094',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=78094&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=78094',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=78094',
#       'hotelKanaName': 'ろわじーるすぱたわーなは',
#       'hotelSpecial': '天然温泉を24時間楽しめる客室有！全室バルコニー付、24時間利用できるフィットネスジム完備',
#       'hotelMinCharge': 7968,
#       'latitude': 94353.28,
#       'longitude': 459606.91,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西3-2-1',
#       'telephoneNo': '098-868-2222',
#       'faxNo': '098-860-2000',
#       'access': '【車】那覇空港より約7分（那覇うみそらトンネル～西海岸道路経由）\u3000【ゆいレール】「旭橋」駅下車、徒歩約15分',
#       'parkingInformation': '1泊1,800円/台',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/78094.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094_kya.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/78094.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/78094/78094map.gif',
#       'reviewCount': 472,
#       'reviewAverage': 4.3,
#       'userReview': '毎年、家族でお世話になっています。プールもあり大浴場、露天風呂、サウナ１日じゃ足りないくらいです。今回は12階のバーも利用させてもらいました。また来年もリラックスしに行きたいです。\u30002023-04-06 11:41:10投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.11,
#       'locationAverage': 4,
#       'roomAverage': 4.35,
#       'equipmentAverage': 4.29,
#       'bathAverage': 4.51,
#       'mealAverage': 3.83}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178447,
#       'hotelName': 'ＨＯＴＥＬ\u3000ＳＡＮＳＵＩ\u3000ＮＡＨＡ\u3000琉球温泉\u3000波之上の湯',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178447',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178447&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178447',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178447',
#       'hotelKanaName': 'ほてる\u3000さんすい\u3000なは\u3000りゅうきゅうおんせん\u3000なみのうえおんせん',
#       'hotelSpecial': '癒しの波上温泉とシースループール完備で那覇空港に一番近いスパ＆リゾート',
#       'hotelMinCharge': 4128,
#       'latitude': 94372.73,
#       'longitude': 459616.75,
#       'postalCode': '900-0037',
#       'address1': '沖縄県',
#       'address2': '那覇市辻2-25-1',
#       'telephoneNo': '098-860-7001',
#       'faxNo': '098-894-7303',
#       'access': '空港から車で約8分◆ホテルと那覇空港を結ぶシャトルバスも運行中◆崖の上の「縁結びパワースポット」波上宮まで【徒歩4分】',
#       'parkingInformation': '有り\u300042台\u30001,500円（税込み／泊）\u3000先着順\u3000※高さ制限有（175センチ）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178447.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178447/178447map.gif',
#       'reviewCount': 218,
#       'reviewAverage': 4.03,
#       'userReview': '清潔感がありフロントも親切丁寧です。立地条件もよくリピート間違いなしです。\u30002023-04-19 13:46:54投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.92,
#       'locationAverage': 3.12,
#       'roomAverage': 3.88,
#       'equipmentAverage': 3.98,
#       'bathAverage': 4.12,
#       'mealAverage': 4.11}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 163087,
#       'hotelName': 'ホテルアクアチッタナハ',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=163087',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=163087&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=163087',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=163087',
#       'hotelKanaName': 'ほてるあくあちったなは',
#       'hotelSpecial': '那覇唯一スケルトンプール◆那覇の夜景を望めるナイトプールが人気◆地中海の朝市をコンセプトにした朝食',
#       'hotelMinCharge': 4200,
#       'latitude': 94385.53,
#       'longitude': 459666.2,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島3-2-20',
#       'telephoneNo': '098-866-5000',
#       'faxNo': '098-866-5600',
#       'access': '泊港離島ターミナルより徒歩30秒/美栄橋駅より徒歩7分/国際通りより徒歩約10分/那覇空港より車で約15分/国道58号沿',
#       'parkingInformation': '有 60台 1,200円（税込／泊）高さ制限1.55ｍ ※先着順\u3000その他のお車は近隣駐車場をご案内',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/163087.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/163087.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/163087/163087map.gif',
#       'reviewCount': 328,
#       'reviewAverage': 4.35,
#       'userReview': '朝食や、屋上温水プールがとてもよかった！\u30002023-04-13 10:16:45投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.18,
#       'locationAverage': 4.08,
#       'roomAverage': 4.11,
#       'equipmentAverage': 4.08,
#       'bathAverage': 3.81,
#       'mealAverage': 4.61}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 183747,
#       'hotelName': 'ホテル・アンドルームス那覇ポート',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=183747',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=183747&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=183747',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183747',
#       'hotelKanaName': 'ほてる・あんどるーむすなはぽーと',
#       'hotelSpecial': '那覇空港より車で7分。ルーフトッププールとサウナが楽しめるスタイリッシュ&カジュアルホテル。',
#       'hotelMinCharge': 2970,
#       'latitude': 94352.33,
#       'longitude': 459610.32,
#       'postalCode': '900-0036',
#       'address1': '沖縄県',
#       'address2': '那覇市西2丁目23-1',
#       'telephoneNo': '098-861-8111',
#       'faxNo': '098-861-8851',
#       'access': '那覇空港から車で7分、沖縄都市モノレール線「旭橋駅」から徒歩10分',
#       'parkingInformation': '有\u3000駐車場52台（内、機械式駐車場40台）※先着順、予約不可\u30001,500円(税込)/日',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183747/183747.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/183747.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/183747/183747map.gif',
#       'reviewCount': 78,
#       'reviewAverage': 4.26,
#       'userReview': 'この部屋には3連泊の内後半2泊しました。部屋は30平米と聴いていたが横に長い為実感は無いかなと。景色は港も見え良いが結構夜中も車が通る道路沿いで上階の部屋だが通過音がよく聞こえるかんじで就寝時は起…\u30002023-04-20 14:42:11投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=183747" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.99,
#       'locationAverage': 3.78,
#       'roomAverage': 4.37,
#       'equipmentAverage': 4.08,
#       'bathAverage': 3.8,
#       'mealAverage': 4.26}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 182682,
#       'hotelName': 'コンフォートイン那覇泊港',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=182682',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=182682&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=182682',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182682',
#       'hotelKanaName': 'こんふぉーといんなはとまりこう',
#       'hotelSpecial': 'ポイント最大10倍得旅キャンペーン参加◆バストイレ別◆無料朝食◆小学生まで添寝無料◆美栄橋駅徒歩5分',
#       'hotelMinCharge': 3200,
#       'latitude': 94382.52,
#       'longitude': 459664.11,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島3-1-4',
#       'telephoneNo': '098-866-4711',
#       'faxNo': '098-866-4710',
#       'access': '沖縄都市モノレール（ゆいレール）「美栄橋」駅より徒歩約5分。国際通りまで徒歩約11分・久茂地まで徒歩約5分。',
#       'parkingInformation': '敷地内駐車場 34台 タワーパーキング先着順\u30001泊1,000円（PM15時〜AM11時）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182682/182682.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/182682.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/182682/182682map.gif',
#       'reviewCount': 172,
#       'reviewAverage': 4.38,
#       'userReview': '美栄橋駅近くの滞在では定宿のひとつになりました部屋も比較的広く、風呂とトイレが別であるのが、メリットになります朝食もゴーヤ（スパム）カレーとタコライス等があり、沖縄の朝食を感じますすぐ…\u30002023-04-20 09:31:45投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=182682" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.29,
#       'locationAverage': 4.32,
#       'roomAverage': 4.25,
#       'equipmentAverage': 3.94,
#       'bathAverage': 4.13,
#       'mealAverage': 3.82}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 178292,
#       'hotelName': 'ホテル\u3000ストレータ那覇',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=178292',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=178292&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=178292',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=178292',
#       'hotelKanaName': 'すとれーたなは',
#       'hotelSpecial': '「美栄橋」から、新しい沖縄らしさを育み、発信していく場所となっていくことを目指しています。',
#       'hotelMinCharge': 4000,
#       'latitude': 94373.92,
#       'longitude': 459670.45,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志1丁目19番8号',
#       'telephoneNo': '098-860-7400',
#       'faxNo': '098-860-7410',
#       'access': 'ゆいレール「美栄橋駅」より徒歩30秒｜那覇空港より車で約16分｜国際通りまで徒歩約5分',
#       'parkingInformation': '立体駐車場48台：\\1,500/1泊\u3000到着順',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/178292.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/178292/178292map.gif',
#       'reviewCount': 187,
#       'reviewAverage': 4.4,
#       'userReview': '朝食が選べる所がとてもよかったです。立地も国際通りから近いですしまた機会があればよろしくお願いします。\u30002023-03-31 16:04:25投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.09,
#       'locationAverage': 4.82,
#       'roomAverage': 4.18,
#       'equipmentAverage': 4.03,
#       'bathAverage': 3.86,
#       'mealAverage': 4.21}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 171943,
#       'hotelName': '沖縄かりゆしリゾートエグゼス那覇＜県庁前＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=171943',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=171943&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=171943',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943',
#       'hotelKanaName': 'おきなわ\u3000かりゆし\u3000りぞーと\u3000えぐぜす\u3000なは',
#       'hotelSpecial': '那覇市内トップクラスの客室広さを誇るラグジュアリーホテル。朝食は全室ルームサービス（お部屋食）',
#       'hotelMinCharge': 7650,
#       'latitude': 94353.21,
#       'longitude': 459643.86,
#       'postalCode': '900-0021',
#       'address1': '沖縄県',
#       'address2': '那覇市泉崎1-11-5',
#       'telephoneNo': '098-860-3300',
#       'faxNo': '098-860-3450',
#       'access': '那覇空港から車で約10分。モノレールご利用の場合は那覇空港駅→県庁前駅13分、下車、徒歩約4分。',
#       'parkingInformation': '有り\u3000４２台\u3000１５００円（税込／泊）\u3000満車の場合は周辺のコインパーキングをご利用くださいませ。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/171943.jpg',
#       'roomImageUrl': None,
#       'roomThumbnailUrl': None,
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/171943/171943map.gif',
#       'reviewCount': 89,
#       'reviewAverage': 4.7,
#       'userReview': '高級感もあり、立地も良いです。国際通りもモノレール、バターミナルも徒歩圏内で、コンビニもとなりに2軒並んでおり、とにかく何にも困ることがありません。那覇市内でとにかく広い部屋に泊まりたい方にも…\u30002023-04-21 00:08:01投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=171943" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.67,
#       'locationAverage': 4.65,
#       'roomAverage': 4.79,
#       'equipmentAverage': 4.6,
#       'bathAverage': 4.6,
#       'mealAverage': 4.66}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 73870,
#       'hotelName': 'コンフォートホテル那覇県庁前',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=73870',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=73870&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=73870',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=73870',
#       'hotelKanaName': 'こんふぉーとほてるなはけんちょうまえ',
#       'hotelSpecial': 'ポイント最大10倍！得旅キャンペーン参加◆無料朝食◆小学6年生まで添い寝無料◆国際通り徒歩３分',
#       'hotelMinCharge': 3150,
#       'latitude': 94354.31,
#       'longitude': 459645.66,
#       'postalCode': '900-0015',
#       'address1': '沖縄県',
#       'address2': '那覇市久茂地1-3-11',
#       'telephoneNo': '098-941-7311',
#       'faxNo': '098-941-7312',
#       'access': 'モノレール（ゆいレール）県庁前駅徒歩３分◆那覇空港モノレール１３分・車１０分◆沖縄県庁、国際通り徒歩３分',
#       'parkingInformation': '1泊820円（15：00〜翌12：00）敷地内駐車場5台',
#       'nearestStation': None,
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/73870.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870_sig.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/73870.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/73870/73870map.gif',
#       'reviewCount': 2714,
#       'reviewAverage': 4.18,
#       'userReview': '4月19日から2泊しました。フロントの方の対応と笑顔が最高でした。朝食も平日だったこともあり、ゆったりいただけました。欲を言えば客室のエアコンが全館コントロールなところが残念かな？\u30002023-04-21 09:53:00投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.15,
#       'locationAverage': 4.6,
#       'roomAverage': 3.98,
#       'equipmentAverage': 3.67,
#       'bathAverage': 3.34,
#       'mealAverage': 3.8}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 56974,
#       'hotelName': 'ホテルルートイン那覇泊港',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=56974',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=56974&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=56974',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=56974',
#       'hotelKanaName': 'ほてるるーといん\u3000なはとまりこう\u3000るーといんなはまえじま',
#       'hotelSpecial': '&#9830;14階展望大浴場完備&#9830;朝食無料サービス&#9830;WOWOW無料視聴可能',
#       'hotelMinCharge': 4050,
#       'latitude': 94384.67,
#       'longitude': 459667.7,
#       'postalCode': '900-0016',
#       'address1': '沖縄県',
#       'address2': '那覇市前島2-12-5',
#       'telephoneNo': '098-866-0700',
#       'faxNo': '098-866-0710',
#       'access': '那覇空港より車で約１０分（４．５ｋｍ）/モノレール美栄橋駅より徒歩５分。',
#       'parkingInformation': '有り\u3000７２台\u3000５００円（税込み／泊）\u3000先着順\u3000（立体駐車場の為、高さ制限有１．５５mまで）',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/56974/56974.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/56974.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/56974/56974_da.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/56974.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/56974/56974map.gif',
#       'reviewCount': 1217,
#       'reviewAverage': 4.17,
#       'userReview': '朝食、大浴場、スタッフの方々の対応と大変良かったです。また利用させていただきたいと思います。\u30002023-04-16 17:08:15投稿'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.08,
#       'locationAverage': 4.25,
#       'roomAverage': 3.82,
#       'equipmentAverage': 3.94,
#       'bathAverage': 4.17,
#       'mealAverage': 4.02}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 196,
#       'hotelName': 'ＣＯＭＭＵＮＩＴＹ＆ＳＰＡ\u3000那覇セントラルホテル',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=196',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=196&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=196',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=196',
#       'hotelKanaName': 'なは\u3000せんとらるほてる',
#       'hotelSpecial': '国際通りまで徒歩約1分の好立地！併設の天然温泉では13種類のお風呂とサウナが滞在中何度でも利用可！',
#       'hotelMinCharge': 3135,
#       'latitude': 94371.5,
#       'longitude': 459685.55,
#       'postalCode': '900-0013',
#       'address1': '沖縄県',
#       'address2': '那覇市牧志2-16-36',
#       'telephoneNo': '098-862-6070',
#       'faxNo': '098-862-6109',
#       'access': '牧志バス停、モノレ－ル美栄橋駅牧志駅より徒歩約5分。美栄橋駅限定で無料送迎有り\u3000駅到着時連絡（10時～20時迄）',
#       'parkingInformation': '有り\u300080台\u3000普通車（1泊1台￥1,500税込）\u3000※予約不要（先着順）・24時間出し入れ可',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/196/196.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/196.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/196/196_room.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/196.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/196/196map.gif',
#       'reviewCount': 536,
#       'reviewAverage': 4.04,
#       'userReview': '国際通りから数分でいけて、とても便利でした。子供連れだったので、チェックイン前にもかかわらず、ベビーカーを貸していただき、大変助かりました。お風呂もジャグジー風呂が多くサウナも3種類あって、歩き疲…\u30002023-04-13 19:25:53投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=196" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 3.96,
#       'locationAverage': 4.39,
#       'roomAverage': 3.81,
#       'equipmentAverage': 3.57,
#       'bathAverage': 3.94,
#       'mealAverage': 4.06}}]},
#   {'hotel': [{'hotelBasicInfo': {'hotelNo': 18195,
#       'hotelName': 'サンプラザホテル＜沖縄県＞',
#       'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=18195',
#       'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=18195&f_flg=PLAN',
#       'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=18195',
#       'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=18195',
#       'hotelKanaName': 'さんぷらざほてる＜おきなわけん＞',
#       'hotelSpecial': 'ゆいレール牧志駅から徒歩5分。那覇のメインストリート国際通り近く、大浴場・コインランドリー有。',
#       'hotelMinCharge': 2000,
#       'latitude': 94378.86,
#       'longitude': 459694.79,
#       'postalCode': '902-0067',
#       'address1': '沖縄県',
#       'address2': '那覇市安里138',
#       'telephoneNo': '098-866-0920',
#       'faxNo': '098-866-0929',
#       'access': '那覇空港から車で約15分・モノレール牧志駅から徒歩5分・崇元寺バス停前徒歩0分',
#       'parkingInformation': '有り\u3000先着順40台予約不可￥1000/泊※バス・大型車などの駐車は電話でお問合せ下さい。',
#       'nearestStation': '那覇空港',
#       'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195.jpg',
#       'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/18195.jpg',
#       'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195_y.jpg',
#       'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/18195.jpg',
#       'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/18195/18195map.gif',
#       'reviewCount': 2625,
#       'reviewAverage': 4.13,
#       'userReview': 'アメニティは必要最小限でした。また朝食もそんなに品数は多くありませんでした。しかし清潔でしたし、宿泊料金と照らし合わせると非常にコスパが高く非常に満足できるものでした。この宿泊料金で不…\u30002023-04-20 15:21:18投稿 <a href="https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=18195" class="3click">つづきはこちら</a>'}},
#     {'hotelRatingInfo': {'serviceAverage': 4.07,
#       'locationAverage': 4.19,
#       'roomAverage': 3.7,
#       'equipmentAverage': 3.52,
#       'bathAverage': 4.12,
#       'mealAverage': 3.9}}]}]}

# %% [markdown]
# ## 4.全体像：取得したデータをエクセルのように扱う

# %% [markdown]
# ### 4.1.実際にやる事

# %% [markdown]
# APIから得られたjsonで得られたデータを確認します。
# jsonだと人間にはわかりずらく、データ加工が難しいため、pandasを使ってエクセルのように変換します。

# %%
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']['hotelName']　を変数を扱う事で、どのホテルのデータでも見れるようにしましょう。
# i = 0として１つ目のホテルの情報を見てみましょう。

i = 0
print(result['hotels'][i]['hotel'][0]['hotelBasicInfo']['hotelName'])
print(result['hotels'][i]['hotel'][0]['hotelBasicInfo']['hotelMinCharge'])
print(result['hotels'][i]['hotel'][0]['hotelBasicInfo']['reviewAverage'])
# Out:
# ハイアットリージェンシー那覇沖縄
# 7106
# 4.65

# %% [markdown]
# ### 4.2.データの確認と扱い方

# %% [markdown]
# 取得しただけではデータを活用できないので、取得したデータを扱っていきます。
#
# 全体像としては
# - 取得したjsonデータを確認
# - jsonでは確認しずらく、扱いずらいので、pandasというライブラリを使って扱いやすくする

# %% [markdown]
# #### 取得したデータの中身を詳しく確認してみましょう。

# %% [markdown]
# ※取得したデータの全体像

# %% [markdown]
# <img style="background-color:#fff;" src="img/img034.png">
# <img style="background-color:#fff;" src="img/img035.png">

# %% [markdown]
# 参照：https://jsoncrack.com/editor

# %% [markdown]
# 取得したデータの内容は result['hotels'][ここ行の場所]['hotel'][0]['hotelBasicInfo'] に格納されており、
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']とすることで、１つ目に格納されているホテルの詳細を取得する事ができます

# %%
result['hotels'][0]['hotel'][0]['hotelBasicInfo']
# Out:
# {'hotelNo': 134763,
#  'hotelName': 'ダイワロイネットホテル那覇おもろまち',
#  'hotelInformationUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/dQ4dX/?f_no=134763',
#  'planListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=134763&f_flg=PLAN',
#  'dpPlanListUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/TDZXm/?noTomariHotel=134763',
#  'reviewUrl': 'https://img.travel.rakuten.co.jp/image/tr/api/hs/RmfmX/?f_hotel_no=134763',
#  'hotelKanaName': 'だいわろいねっとほてるなはおもろまち',
#  'hotelSpecial': '海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎',
#  'hotelMinCharge': 4050,
#  'latitude': 94389.24,
#  'longitude': 459709.57,
#  'postalCode': '900-0006',
#  'address1': '沖縄県',
#  'address2': '那覇市おもろまち1-1-12',
#  'telephoneNo': '098-862-4555',
#  'faxNo': '098-862-4556',
#  'access': 'ゆいレール\u3000おもろまち駅より徒歩５分\u3000国際通りより車で5分',
#  'parkingInformation': '1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用下さい。',
#  'nearestStation': None,
#  'hotelImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763.jpg',
#  'hotelThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/90/134763.jpg',
#  'roomImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763_tw.jpg',
#  'roomThumbnailUrl': 'https://img.travel.rakuten.co.jp/HIMG/INTERIOR/134763.jpg',
#  'hotelMapImageUrl': 'https://img.travel.rakuten.co.jp/share/HOTEL/134763/134763map.gif',
#  'reviewCount': 942,
#  'reviewAverage': 4.4,
#  'userReview': '前回は旅行支援パッケージを利用し良かったので，再度宿泊致しました。今回は20倍ポイントに惹かれてしまいました。接客も非常によく、数日を有意義に過ごせました。またリピートしたいです。\u30002023-03-26 20:06:49投稿'}

# %% [markdown]
# どんなホテルの詳細情報項目があるか確認してみましょう！
# result['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()で確認することができます。

# %%
# result['hotels'][0]['hotel'][0]['hotelBasicInfo']になんの項目が含まれているかをkeys()で確認できます。
result['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()
# Out:
# dict_keys(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl', 'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial', 'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1', 'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation', 'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl', 'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage', 'userReview'])

# %% [markdown]
# hotelNameという項目があるので、ホテルの名前などを取得してみましょう

# %%
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['hotelName']
# Out:
# 'ダイワロイネットホテル那覇おもろまち'

# %%
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['planListUrl']
# Out:
# 'https://img.travel.rakuten.co.jp/image/tr/api/hs/cHNRi/?f_no=134763&f_flg=PLAN'

# %%
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['hotelMinCharge']
# Out:
# 4050

# %%
result['hotels'][0]['hotel'][0]['hotelBasicInfo']['reviewAverage']
# Out:
# 4.4

# %% [markdown]
# #### データを扱いやすくするために可視化する

# %% [markdown]
# ##### pandasを使ったデータの可視化

# %% [markdown]
# APIで得られたデータをpandasを用いてエクセルのような見やすいデータに変換してみましょう！

# %% [markdown]
# ライブラリのpandasをインポートしましょう！
# as pdとつけて、短くpdとコーディングできるようにします。

# %%
import pandas as pd

# %% [markdown]
# データをpandasのDataFrameに格納してみましょう！
# また、DataFrameとはどのような変換をしてくれるか確認してみましょう。

# %%
# １つめのホテルのデータをhotel_infoに代入します。
hotel_info = result['hotels'][0]['hotel'][0]['hotelBasicInfo']

# pd.DataFrame(ここに変換したいデータ,index=[ここにpandasに認識してほしい行数indexの番号])を代入します。
pd.DataFrame(hotel_info,index=[0])
# Out:
#    hotelNo           hotelName  \
# 0   134763  ダイワロイネットホテル那覇おもろまち
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl       hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  だいわろいねっとほてるなはおもろまち
#
#                                         hotelSpecial  hotelMinCharge  \
# 0  海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎            4050
#
#    latitude  ...                                 parkingInformation  \
# 0  94389.24  ...  1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用...
#
#   nearestStation                                      hotelImageUrl  \
# 0           None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                    hotelThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/90/13476...
#
#                                         roomImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                     roomThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                     hotelMapImageUrl reviewCount  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...         942
#
#   reviewAverage                                         userReview
# 0           4.4  前回は旅行支援パッケージを利用し良かったので，再度宿泊致しました。今回は20倍ポイントに惹か...
#
# [1 rows x 27 columns]

# %% [markdown]
# indexの数字を変数iにして、他のホテル情報も確認してみましょう！
# iの数字を変えると取得できるホテルを変更できる事も確認してみましょう

# %%
i = 0 #index番号の指定。ここの数字を変えると格納されるデータが変わります。

# その番号に対応するホテル情報を取得し、hotel_infoに代入
hotel_info = result['hotels'][i]['hotel'][0]['hotelBasicInfo']

# pd.DataFrame(ここに変換したいデータ,index=[ここにpandasに認識してほしい行数indexの番号])を代入します。
pd.DataFrame(hotel_info,index=[i])
# Out:
#    hotelNo           hotelName  \
# 0   134763  ダイワロイネットホテル那覇おもろまち
#
#                                  hotelInformationUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                          planListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                        dpPlanListUrl  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                            reviewUrl       hotelKanaName  \
# 0  https://img.travel.rakuten.co.jp/image/tr/api/...  だいわろいねっとほてるなはおもろまち
#
#                                         hotelSpecial  hotelMinCharge  \
# 0  海も見える最上階18階での朝食が評判！■客室階は全室10階以上♪■高速道路、西原IC近く観光にも◎            4050
#
#    latitude  ...                                 parkingInformation  \
# 0  94389.24  ...  1台1,100円(1泊)先着順。ホテル1階に専用P有＊満車時は提携P（1,100円）をご利用...
#
#   nearestStation                                      hotelImageUrl  \
# 0           None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                    hotelThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/90/13476...
#
#                                         roomImageUrl  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                     roomThumbnailUrl  \
# 0  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
#
#                                     hotelMapImageUrl reviewCount  \
# 0  https://img.travel.rakuten.co.jp/share/HOTEL/1...         942
#
#   reviewAverage                                         userReview
# 0           4.4  前回は旅行支援パッケージを利用し良かったので，再度宿泊致しました。今回は20倍ポイントに惹か...
#
# [1 rows x 27 columns]

# %% [markdown]
# 個別のデータを格納できたので、データ全体を格納してみましょう。
#
# そのためにAPIで取得したホテルのデータ数を確認してみましょう！
# len(確認したい配列)でデータ数を確認できます！

# %%
# len(ここに配列に含まれる要素)で配列に含まれる要素の数を取得できます。
len(result['hotels'])
# Out:
# 30

# %% [markdown]
# 30あるホテルのデータをfor文を使ってまとめてみましょう！

# %%
#空のpandasデータフレームを用意して、生成した1つ１つのデータフレームをこのdfに結合して１つにします。
df = pd.DataFrame()

# iにrange(0,len(result['hotels']))である0～29の数字が１つずつ代入されて実行されます。
# 今回は30のデータとわかっているのでfor i in range(0,30)でも問題ないですが、30とは限らないのでデータ園生数であるlen(result['hotels'])を使います。
for i in range(0,len(result['hotels'])):
    hotel_info = result['hotels'][i]['hotel'][0]['hotelBasicInfo'] #格納する配列をhotel_infoに代入する
    temp_df = pd.DataFrame(hotel_info,index=[i]) #hotel_infoに代入されたホテルのデータをデータフレームに変換します。
    df = pd.concat([df,temp_df]) #dfに結合して１つにまとめます。

# %% [markdown]
# まとめたデータをdisplay(df) で確認してみましょう！

# %%
display(df)

# %% [markdown]
# df.columnsで項目の確認ができます！
# これはresult['hotels'][0]['hotel'][0]['hotelBasicInfo'].keys()で取得した値と一致します

# %%
df.columns
# Out:
# Index(['hotelNo', 'hotelName', 'hotelInformationUrl', 'planListUrl',
#        'dpPlanListUrl', 'reviewUrl', 'hotelKanaName', 'hotelSpecial',
#        'hotelMinCharge', 'latitude', 'longitude', 'postalCode', 'address1',
#        'address2', 'telephoneNo', 'faxNo', 'access', 'parkingInformation',
#        'nearestStation', 'hotelImageUrl', 'hotelThumbnailUrl', 'roomImageUrl',
#        'roomThumbnailUrl', 'hotelMapImageUrl', 'reviewCount', 'reviewAverage',
#        'userReview'],
#       dtype='object')

# %% [markdown]
# ##### pandasを使ったデータ整理

# %% [markdown]
# まとめたデータから名前と値段と評価だけを取り出してみましょう！
# １つのカラムを取得する時は欲しいカラム名である"カラム名"を代入したdf["カラム名"]で取得できましたが、
# 複数選択する場合は、の代わりに配列である["カラム名1","カラム名2","カラム名3"]を代入してdf[["カラム名1","カラム名2","カラム名3"]]とする必要があります。

# %%
df[[ 'hotelName', 'hotelMinCharge', 'reviewAverage']]
# Out:
#                           hotelName  hotelMinCharge  reviewAverage
# 0                ダイワロイネットホテル那覇おもろまち            4050           4.40
# 1                         東急ステイ沖縄那覇            4350           4.60
# 2                  ハイアットリージェンシー那覇沖縄            8473           4.65
# 3                  ダイワロイネットホテル沖縄県庁前            4500           4.26
# 4                      ヒューイットリゾート那覇            5390           4.26
# 5                     ホテルリソルトリニティ那覇            4900           4.47
# 6              沖縄逸の彩（ひので）　温泉リゾートホテル            5200           4.40
# 7      ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯            4859           4.03
# 8                        ロワジールホテル那覇            4377           4.05
# 9          ホテルグランコンソルト那覇（２０２２年９月開業）            5000           4.60
# 10                       ホテル　ロコア　ナハ            6650           4.42
# 11               ホテルパームロイヤルNAHA国際通り            3900           4.31
# 12                     リーガロイヤルグラン沖縄            7733           4.61
# 13                  ＪＲ九州ホテル　ブラッサム那覇            6300           4.47
# 14                ダイワロイネットホテル那覇国際通り            3750           4.39
# 15                      ホテルアクアチッタナハ            4265           4.37
# 16                      ホテルグレイスリー那覇            5050           4.49
# 17               ＯＭＯ５沖縄那覇　ｂｙ　星野リゾート            5500           4.22
# 18                     コンフォートイン那覇泊港            3950           4.41
# 19                 ホテル・アンドルームス那覇ポート            3600           4.29
# 20                         ノボテル沖縄那覇            4316           4.34
# 21                        ホテルコレクティブ            8550           4.80
# 22                     ホテル　アンテルーム那覇            5125           4.47
# 23                     沖縄ハーバービューホテル            3375           4.20
# 24                     ロワジールスパタワー那覇            8798           4.23
# 25  アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)            5170           4.43
# 26                        那覇ウエスト・イン            3080           4.29
# 27                      ワイズイン那覇小禄駅前            2960           4.36
# 28                      ホテル　ストレータ那覇            5525           4.40
# 29                   コンフォートホテル那覇県庁前            3750           4.16

# %% [markdown]
# 欲しいデータに絞って出力してみましょう！
# pandasの機能であるto_csvを使うとcsvファイルとして保存ができます

# %%
# dfの'hotelName', 'hotelInformationUrl', 'hotelMinCharge', 'telephoneNo', 'reviewAverage'を指定して、
# ここにデータフレーム.to_csv(ここにファイル名,データフレームで認識されているindex数字も出力するかどうか)で保存できます。
# このデータではindexの数字は必要ないので、index = Falseにします。

df[[ 'hotelName', 'hotelInformationUrl', 
       'hotelMinCharge', 'telephoneNo', 'reviewAverage',
       ]].to_csv('hotel.csv',index = False),
# Out:
# (None,)

# %% [markdown]
# 今度は保存したcsvをdf2として読み込んでみましょう！

# %%
# pd.read_csv(ここにファイル名)でロードして、df2に代入します。
df2 = pd.read_csv("hotel.csv")
df2
# Out:
#                           hotelName  \
# 0                ダイワロイネットホテル那覇おもろまち
# 1                  ハイアットリージェンシー那覇沖縄
# 2                  ダイワロイネットホテル沖縄県庁前
# 3                         東急ステイ沖縄那覇
# 4                      ヒューイットリゾート那覇
# 5                     ホテルリソルトリニティ那覇
# 6                ホテルパームロイヤルNAHA国際通り
# 7                 ダイワロイネットホテル那覇国際通り
# 8                        ホテル　ロコア　ナハ
# 9                      リーガロイヤルグラン沖縄
# 10                      ホテルグレイスリー那覇
# 11                  ＪＲ九州ホテル　ブラッサム那覇
# 12     ＨＯＴＥＬ　ＳＡＮＳＵＩ　ＮＡＨＡ　琉球温泉　波之上の湯
# 13             沖縄逸の彩（ひので）　温泉リゾートホテル
# 14                       ロワジールホテル那覇
# 15                     ロワジールスパタワー那覇
# 16                     沖縄ハーバービューホテル
# 17                      ホテルアクアチッタナハ
# 18                        ホテルコレクティブ
# 19                 ホテル・アンドルームス那覇ポート
# 20  アルモントホテル那覇おもろまち(旧ホテル法華クラブ那覇新都心)
# 21                    サンプラザホテル＜沖縄県＞
# 22               ＯＭＯ５沖縄那覇　ｂｙ　星野リゾート
# 23                   リッチモンドホテル那覇久茂地
# 24                         ノボテル沖縄那覇
# 25                      ホテル　ストレータ那覇
# 26            沖縄かりゆしリゾートエグゼス那覇＜県庁前＞
# 27                   コンフォートホテル那覇県庁前
# 28                ホテルＪＡＬシティ那覇（国際通り）
# 29                     コンフォートイン那覇泊港
#
#                                   hotelInformationUrl  hotelMinCharge  \
# 0   https://img.travel.rakuten.co.jp/image/tr/api/...            3500
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...            9200
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...            4000
# 3   https://img.travel.rakuten.co.jp/image/tr/api/...            4700
# 4   https://img.travel.rakuten.co.jp/image/tr/api/...            6090
# 5   https://img.travel.rakuten.co.jp/image/tr/api/...            5800
# 6   https://img.travel.rakuten.co.jp/image/tr/api/...            4318
# 7   https://img.travel.rakuten.co.jp/image/tr/api/...            4350
# 8   https://img.travel.rakuten.co.jp/image/tr/api/...            6650
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...            8000
# 10  https://img.travel.rakuten.co.jp/image/tr/api/...            6700
# 11  https://img.travel.rakuten.co.jp/image/tr/api/...            6800
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...            4386
# 13  https://img.travel.rakuten.co.jp/image/tr/api/...            5600
# 14  https://img.travel.rakuten.co.jp/image/tr/api/...            7140
# 15  https://img.travel.rakuten.co.jp/image/tr/api/...            9244
# 16  https://img.travel.rakuten.co.jp/image/tr/api/...            3375
# 17  https://img.travel.rakuten.co.jp/image/tr/api/...            5059
# 18  https://img.travel.rakuten.co.jp/image/tr/api/...            8350
# 19  https://img.travel.rakuten.co.jp/image/tr/api/...            4320
# 20  https://img.travel.rakuten.co.jp/image/tr/api/...            5000
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...            3000
# 22  https://img.travel.rakuten.co.jp/image/tr/api/...            6200
# 23  https://img.travel.rakuten.co.jp/image/tr/api/...            3170
# 24  https://img.travel.rakuten.co.jp/image/tr/api/...            4987
# 25  https://img.travel.rakuten.co.jp/image/tr/api/...            5100
# 26  https://img.travel.rakuten.co.jp/image/tr/api/...            9350
# 27  https://img.travel.rakuten.co.jp/image/tr/api/...            4000
# 28  https://img.travel.rakuten.co.jp/image/tr/api/...            5300
# 29  https://img.travel.rakuten.co.jp/image/tr/api/...            4050
#
#      telephoneNo  reviewAverage
# 0   098-862-4555           4.39
# 1   098-866-8888           4.67
# 2   098-860-1855           4.22
# 3   098-833-1090           4.57
# 4   098-943-8325           4.25
# 5   098-863-9269           4.48
# 6   098-865-5551           4.34
# 7   098-868-9055           4.41
# 8   098-868-6578           4.45
# 9   098-867-3331           4.61
# 10  098-867-6111           4.48
# 11  098-861-8700           4.46
# 12  098-860-7001           4.01
# 13  098-863-8877           4.41
# 14  098-868-2222           4.10
# 15  098-868-2222           4.23
# 16  098-853-2111           4.18
# 17  098-866-5000           4.40
# 18  098-860-8366           4.77
# 19  098-861-8111           4.30
# 20  098-860-6611           4.40
# 21  098-866-0920           4.12
# 22   05031348095           4.23
# 23  098-869-0077           4.18
# 24  098-887-1111           4.33
# 25  098-860-7400           4.40
# 26  098-860-3300           4.67
# 27  098-941-7311           4.18
# 28  098-866-2580           4.34
# 29  098-866-4711           4.41

# %% [markdown]
# まとめたデータから評価が4.5以上のホテルを検索してみましょう！

# %%
# df[ ここにそれぞれの行に対して出力するかどうかの条件文　]でデータを抽出できます。
# 今回は評価が4.5以上なので、df['reviewAverage'] > 4.5を条件とします。
df[ df['reviewAverage'] > 4.5]
# Out:
#     hotelNo                 hotelName  \
# 1    177761                 東急ステイ沖縄那覇
# 2    148000          ハイアットリージェンシー那覇沖縄
# 9    183095  ホテルグランコンソルト那覇（２０２２年９月開業）
# 12   136808              リーガロイヤルグラン沖縄
# 21   172986                 ホテルコレクティブ
#
#                                   hotelInformationUrl  \
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                           planListUrl  \
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                         dpPlanListUrl  \
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...
#
#                                             reviewUrl       hotelKanaName  \
# 1   https://img.travel.rakuten.co.jp/image/tr/api/...    とうきゅうすてい　おきなわ　なは
# 2   https://img.travel.rakuten.co.jp/image/tr/api/...  はいあっとりーじぇんしーなはおきなわ
# 9   https://img.travel.rakuten.co.jp/image/tr/api/...       ほてるぐらんこんそるとなは
# 12  https://img.travel.rakuten.co.jp/image/tr/api/...      りーがろいやるぐらんおきなわ
# 21  https://img.travel.rakuten.co.jp/image/tr/api/...              これくてぃぶ
#
#                                          hotelSpecial  hotelMinCharge  \
# 1   食事評価4.2★沖縄料理が満載♪空港からゆいレールで4駅の好立地、全室洗濯乾燥機&ミニキッチ...            4350
# 2     グローバルブランドならではの洗練されたおもてなしと空間で上質なホテルステイをお楽しみください。            8473
# 9   2022年9月OPEN！ご宿泊者様専用ラウンジ・コネクティングルーム・駐車場を完備。国際通り...            5000
# 12  5と0の日クーポン対象★ゆいレール旭橋駅直結！「リーガ・マルシェ」スタッフ厳選の無料アメニティバー            7733
# 21  ★★ ご宿泊者専用屋外プール 2023年4月1日(土)〜2023年10月31日(火)　オープ...            8550
#
#     latitude  ...                                 parkingInformation  \
# 1   94334.89  ...  屋内契約駐車場30台 1500円 入出庫可 屋内提携駐車場123台 1200円 1回出庫毎に...
# 2   94357.69  ...  立体駐車場・地下駐車場完備　１１３台　1泊1台あたり1,500円（税込）　（予約不要／出し入...
# 9   94350.11  ...                有り：28台　料金：1,650円/泊 (税込み）高さ制限がございます。
# 12  94344.00  ...        有り　料金：1台1泊1,500円（税・サ込）ご宿泊の皆様にバレーパーキング対応致します
# 21  94359.78  ...                                      有り(１,５００円／1日)
#
#    nearestStation                                      hotelImageUrl  \
# 1            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 2            None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 9            那覇空港  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 12             旭橋  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 21           None  https://img.travel.rakuten.co.jp/share/HOTEL/1...
#
#                                     hotelThumbnailUrl  \
# 1   https://img.travel.rakuten.co.jp/HIMG/90/17776...
# 2   https://img.travel.rakuten.co.jp/HIMG/90/14800...
# 9   https://img.travel.rakuten.co.jp/HIMG/90/18309...
# 12  https://img.travel.rakuten.co.jp/HIMG/90/13680...
# 21  https://img.travel.rakuten.co.jp/HIMG/90/17298...
#
#                                          roomImageUrl  \
# 1                                                None
# 2   https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 9                                                None
# 12  https://img.travel.rakuten.co.jp/share/HOTEL/1...
# 21                                               None
#
#                                      roomThumbnailUrl  \
# 1                                                None
# 2   https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 9                                                None
# 12  https://img.travel.rakuten.co.jp/HIMG/INTERIOR...
# 21                                               None
#
#                                      hotelMapImageUrl reviewCount  \
# 1   https://img.travel.rakuten.co.jp/share/HOTEL/1...         526
# 2   https://img.travel.rakuten.co.jp/share/HOTEL/1...         603
# 9   https://img.travel.rakuten.co.jp/share/HOTEL/1...          40
# 12  https://img.travel.rakuten.co.jp/share/HOTEL/1...         590
# 21  https://img.travel.rakuten.co.jp/share/HOTEL/1...          83
#
#    reviewAverage                                         userReview
# 1           4.60  部屋が広く綺麗でとても快適でした！洗濯機が部屋の中にあるのは大変助かります。スタッフの方も親...
# 2           4.65  立地もよく部屋の掃除も行き届いていて、スタッフの方々も気持ち良い接客でホテル全体のインテリア...
# 9           4.60  子供との旅行で一泊泊まりました。県庁駅も国際通りも近く、とても便利でした。お部屋はピカピカで...
# 12          4.61  部屋からの眺望はいまいちでしたが、それ以外は全てすばらしかったです。今までは他のホテルを利用...
# 21          4.80  とてもきれいで、立地も良く今まで利用したホテルの中でも最高ランクに値するホテルです。また沖縄...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 課題

# %% [markdown]
# 検索して絞ったデータをdf2に格納して、ホテル名と評価とレビューだけ出力してみましょう！

# %%
df2 = df[ df['reviewAverage'] > 4.5]
df2 = df2[['hotelName','reviewAverage','userReview']]
display(df2)
# Out:
#                    hotelName  reviewAverage  \
# 1                  東急ステイ沖縄那覇           4.60
# 2           ハイアットリージェンシー那覇沖縄           4.65
# 9   ホテルグランコンソルト那覇（２０２２年９月開業）           4.60
# 12              リーガロイヤルグラン沖縄           4.61
# 21                 ホテルコレクティブ           4.80
#
#                                            userReview
# 1   部屋が広く綺麗でとても快適でした！洗濯機が部屋の中にあるのは大変助かります。スタッフの方も親...
# 2   立地もよく部屋の掃除も行き届いていて、スタッフの方々も気持ち良い接客でホテル全体のインテリア...
# 9   子供との旅行で一泊泊まりました。県庁駅も国際通りも近く、とても便利でした。お部屋はピカピカで...
# 12  部屋からの眺望はいまいちでしたが、それ以外は全てすばらしかったです。今までは他のホテルを利用...
# 21  とてもきれいで、立地も良く今まで利用したホテルの中でも最高ランクに値するホテルです。また沖縄...

# %% [markdown]
# - 同じ要領で楽天トラベル以外の楽天市場のデータを取得してください。
# - たどったフローを箇条書きまたは図式化してTAに提出してチェックうけてください
# - 発展
#     - 他のサービスのAPIで自分で構造化データまで取得してください。
#     - それを人に説明してください
